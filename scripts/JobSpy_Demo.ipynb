# %%
from jobspy import scrape_jobs
import pandas as pd
from IPython.display import display, HTML
from datetime import datetime
from pymongo import MongoClient
from pydantic import BaseModel
from typing import Optional

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

def scrape():
    jobs = scrape_jobs(
        site_name=["linkedin", "glassdoor", "zip_recruiter", "indeed"],
        search_term="",
        location='USA',
        hyperlinks=True,
        is_remote=True,
        results_wanted=10,
    )
    return jobs

# %%
import re
from typing import Optional
from typing import Any

class Job(BaseModel):
    jobId: str
    title: str
    location: Any
    company: str
    link: str
    jobDescription: Optional[str]
    scapetime: datetime
    jobPosted: datetime

# Function to connect to the MongoDB database
def connect_to_database():
    client = MongoClient('mongodb://localhost:27017/')
    db = client['glassdoor']
    collection = db['jobs']
    return collection

# Function to check for duplicate records in MongoDB
def check_duplicate(job_id):
    collection = connect_to_database()
    return collection.find_one({"jobId": job_id}) is not None

# Extracting jobId from job URLs
def get_job_id(job_url: str, site: str) -> str:
    try:
        if site == 'indeed':
            job_id = re.search(r'(?<=jk=)[\w-]+', job_url).group()
        elif site == 'zip_recruiter':
            job_id = re.search(r'(?<=lvk=)[\w-]+', job_url).group()
        elif site == 'linkedin':
            job_id = re.search(r'(?<=view/)\d+', job_url).group()
        elif site == 'glassdoor':
            job_id = re.search(r'(?<=jl=)\d+', job_url).group()
        else:
            job_id = None
        return job_id
    except Exception as e:
        print(job_url)
        print(site)
        print(str(e))


# Function to get the current datetime
def current_datetime():
    return datetime.now()

# %%
def save_to_mongodb(job : Job):
    collection = connect_to_database()
    item_dict = job.dict()
    if not check_duplicate(item_dict['jobId']):
        collection.insert_one(item_dict)
        print(f"inserted=>{item_dict['jobId']}")
        return True
    return False

jobs = scrape()
# Out:
# 2024-04-22 01:53:21,508 - JobSpy - INFO - LinkedIn search page: 1
# 2024-04-22 01:53:21,509 - JobSpy - INFO - Indeed search page: 1
# 2024-04-22 01:53:21,674 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-04-22 01:53:22,348 - JobSpy - INFO - Indeed finished scraping
# 2024-04-22 01:53:22,348 - JobSpy - INFO - ZipRecruiter finished scraping
# 2024-04-22 01:53:23,592 - JobSpy - INFO - Glassdoor search page: 1
# 2024-04-22 01:53:26,666 - JobSpy - INFO - Glassdoor finished scraping
# 2024-04-22 01:53:32,947 - JobSpy - INFO - Linkedin finished scraping

# %%
# # Assume jobs is your dataframe
for _, item in jobs.iterrows():
    try:
        df_item = item.to_dict()
        jobId = get_job_id(df_item['job_url_hyper'], df_item['site'])

        job = Job(
                jobId=jobId,
                title=df_item['title'],
                location=df_item['location'],
                company=df_item['company'],
                link=df_item['job_url_hyper'],
                jobDescription=df_item['description'],
                scapetime=current_datetime(),
                jobPosted=df_item['date_posted']
            )
        print(jobId)
#         print(job.dict())
        if not save_to_mongodb(job):
            pass
    except Exception as e:
        print(str(e))
# Out:
# 1009247148035
# 1009247236374
# 1009245191473
# 1009187401258
# inserted=>1009187401258
# 1009104134567
# inserted=>1009104134567
# 1009100991693
# inserted=>1009100991693
# 1009081152450
# 1009051881574
# 1008917604697
# 1008903441549
# inserted=>1008903441549
# ced6bbb9dc49160f
# 98c6f4f0cff7544c
# 34893914f9ea7594
# 12d3934d3d0fcbb8
# e03be3cec74f45db
# 7720e9db7f001d0c
# inserted=>7720e9db7f001d0c
# 11e19c0687823e2a
# bac504b7fd10aaaa
# 01e98f9c84d98c60
# inserted=>01e98f9c84d98c60
# bfd0cd505b2a3352
# inserted=>bfd0cd505b2a3352
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# 1 validation error for Job
# jobDescription
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# DRaoKeCrCMKjGxVjqWFdsQ
# p_4fPYY56JnsGJULrRcD6g
# A8I5wFnv7iaWWUUaYYOK1Q
# LaBb2QpqGmD97c8ZY9Z-Vw
# xECwNNfh1fFjeGgh4R6yLg
# op6nYv938j-hDcswxIi8fw
# 9SDljsAsEfwnrn5Qz_yR2w
# inserted=>9SDljsAsEfwnrn5Qz_yR2w
# 7r32HZ5zfel8H6Nq5fZigg
# inserted=>7r32HZ5zfel8H6Nq5fZigg
# wimj-GRFn8SAFfx-ipAGiA
# inserted=>wimj-GRFn8SAFfx-ipAGiA
# dSXXn1vMjERhQlX2QAYE8A
# inserted=>dSXXn1vMjERhQlX2QAYE8A

# %%
# for _, item in jobs.iterrows():
#     jobId = get_job_id(item['job_url_hyper'], item['site'])
#     print(jobId)

# %%
jobs
# Out:
#              site                                      job_url_hyper  \
# 20      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 25      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 28      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 26      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 24      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 29      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 21      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 27      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 22      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 23      glassdoor  <a href="https://www.glassdoor.com/job-listing...
# 0          indeed  <a href="https://www.indeed.com/viewjob?jk=ced...
# 1          indeed  <a href="https://www.indeed.com/viewjob?jk=98c...
# 2          indeed  <a href="https://www.indeed.com/viewjob?jk=348...
# 4          indeed  <a href="https://www.indeed.com/viewjob?jk=12d...
# 6          indeed  <a href="https://www.indeed.com/viewjob?jk=e03...
# 9          indeed  <a href="https://www.indeed.com/viewjob?jk=772...
# 5          indeed  <a href="https://www.indeed.com/viewjob?jk=11e...
# 3          indeed  <a href="https://www.indeed.com/viewjob?jk=bac...
# 8          indeed  <a href="https://www.indeed.com/viewjob?jk=01e...
# 7          indeed  <a href="https://www.indeed.com/viewjob?jk=bfd...
# 36       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 30       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 35       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 38       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 32       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 33       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 34       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 37       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 39       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 31       linkedin  <a href="https://www.linkedin.com/jobs/view/39...
# 12  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 13  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 14  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 16  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 17  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 18  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 11  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 10  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 15  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
# 19  zip_recruiter  <a href="https://www.ziprecruiter.com/jobs//j?...
#
#                                        job_url_direct  \
# 20                                                NaN
# 25                                                NaN
# 28                                                NaN
# 26                                                NaN
# 24                                                NaN
# 29                                                NaN
# 21                                                NaN
# 27                                                NaN
# 22                                                NaN
# 23                                                NaN
# 0   http://www.indeed.com/job/independent-contract...
# 1   http://www.indeed.com/job/elearning-course-dev...
# 2   http://www.indeed.com/job/claims-attorney-3489...
# 4   http://www.indeed.com/job/receptionist-12d3934...
# 6   http://www.indeed.com/job/grant-writer-e03be3c...
# 9   http://www.indeed.com/job/real-estate-agent-77...
# 5   http://www.indeed.com/job/executive-assistant-...
# 3   https://sunlife.wd3.myworkdayjobs.com/Experien...
# 8   https://scck12ia.mysmarthire.com/jobs/14749-42...
# 7   https://honuservices.jobs.net/job/J3N3DB6WBZVX...
# 36                                                NaN
# 30                                                NaN
# 35                                                NaN
# 38                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 37                                                NaN
# 39                                                NaN
# 31                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 11                                                NaN
# 10                                                NaN
# 15                                                NaN
# 19                                                NaN
#
#                                                 title  \
# 20                    Document Drafting Administrator
# 25                                       Receptionist
# 28                               IBM Maximo Developer
# 26                       Associate Director, Accounts
# 24                      Power BI Principal Consultant
# 29                 DAT (Dental Admissions Test) Tutor
# 21                                      Product Owner
# 27            Tax Specialist - Trusts and Individuals
# 22                             CabinetVision Engineer
# 23                                 High Ticket Closer
# 0              Independent Contractor 1099/Consultant
# 1                          eLearning Course Developer
# 2                                     Claims Attorney
# 4                                        Receptionist
# 6                                        Grant Writer
# 9                                   Real Estate Agent
# 5                                 Executive Assistant
# 3                                         Underwriter
# 8                EYS Summer School Special Ed Teacher
# 7    Human Resources Generalist/Onboarding Specialist
# 36                                     Your Role Here
# 30                                 Scheduler - Remote
# 35               Home-Based Hotel Scheduler (Virtual)
# 38                       Product Marketing Specialist
# 32                      People Operations Coordinator
# 33                                   Remote Scheduler
# 34                                Scheduler - Virtual
# 37                                  Virtual Scheduler
# 39                         Scheduler - Work From Home
# 31                          Community Manager- Social
# 12                                       Receptionist
# 13                        Remote Sales Representative
# 14                    Home-Based Sales Representative
# 16  Sales Representative Entry Level  - Work From ...
# 17  Sales Representative Entry Level  - Work From ...
# 18                             Remote Sales Associate
# 11  Customer Service Representative - Remote in Mo...
# 10                  Representative, Sales Experienced
# 15                                 Sr Project Manager
# 19     Remote Licensed Psychiatric Nurse Practitioner
#
#                                           company                   location  \
# 20                                   Confidential               New York, NY
# 25                                           MVSI                        NaN
# 28                                        ITinfra                        NaN
# 26                        Eighty Five Sixty, Inc.                Del Mar, CA
# 24                                    P3 Adaptive                        NaN
# 29                        Inspira Education Group                        NaN
# 21                      AmTote International Inc.                        NaN
# 27                   Brotemarkle, Davis & Co. LLP                        NaN
# 22                              Ellis and Company                        NaN
# 23                 Five Star Body Transformations                        NaN
# 0   Lone Star Enterprise and Consulting Group Inc                 Remote, US
# 1                               Data Products LLC                 Remote, US
# 2             Tokio Marine HCC- Public Risk Group                 Remote, US
# 4                                    MVSI Onboard                 Remote, US
# 6                               Data Products LLC                 Remote, US
# 9                               The Premier Group       Fayetteville, GA, US
# 5                                  Workflow Queen                 Remote, US
# 3                                        Sun Life    Wellesley Hills, MA, US
# 8                       South Central Calhoun CSD                 Remote, US
# 7                                    Na Oiwi Kane                 Remote, US
# 36                                   The Flex Co.            Los Angeles, CA
# 30                        DreamScape Destinations                Houston, TX
# 35                             Historic Hideaways            Los Angeles, CA
# 38                                         Zillow
# 32                                           Loop
# 33                                  Voyage Canvas           Philadelphia, PA
# 34                                  Voyage Canvas              San Diego, CA
# 37                                  Voyage Canvas
# 39                             WanderLuxe Escapes                Phoenix, AZ
# 31                                         NoGood
# 12                            Deborah Schadel Inc          Columbia, SC, USA
# 13                                      SureGuard       Saint Louis, MO, USA
# 14                               Joseph and Young             Miami, FL, USA
# 16                              AO / AIL - Agency       Los Angeles, CA, USA
# 17                               AO / AIL - Group           Chicago, IL, USA
# 18                            The Max Spencer Co.     Grand Prairie, TX, USA
# 11                                          Optum          Franklin, TN, USA
# 10                                        CHS Inc          Missoula, MT, USA
# 15                                       SPECTRUM  Maryland Heights, MO, USA
# 19                                        Headway       Casa Grande, AZ, USA
#
#                           job_type date_posted interval  min_amount  \
# 20                             NaN  2024-04-22      NaN         NaN
# 25                             NaN  2024-04-22   hourly       16.00
# 28                             NaN  2024-04-20   yearly   100000.00
# 26                             NaN  2024-03-15   yearly    95000.00
# 24                             NaN  2024-02-02   yearly   100000.00
# 29                             NaN  2024-02-01   hourly       45.00
# 21                             NaN  2024-01-19      NaN         NaN
# 27                             NaN  2023-12-30   yearly   105000.00
# 22                             NaN  2023-10-11   yearly    65000.00
# 23                             NaN  2023-10-03   yearly    77421.00
# 0     parttime, fulltime, contract  2024-04-22  monthly     5000.00
# 1   parttime, contract, internship  2024-04-22      NaN         NaN
# 2                         fulltime  2024-04-22   yearly         NaN
# 4                         fulltime  2024-04-22   hourly       16.31
# 6               parttime, contract  2024-04-22      NaN         NaN
# 9                         fulltime  2024-04-22   yearly    78000.00
# 5                         fulltime  2024-04-21   yearly         NaN
# 3                              NaN  2024-04-19   yearly    69900.00
# 8                              NaN  2024-04-19   hourly         NaN
# 7                         fulltime  2024-04-18      NaN         NaN
# 36                             NaN  2024-04-20      NaN         NaN
# 30                             NaN  2024-04-19      NaN         NaN
# 35                             NaN  2024-04-19      NaN         NaN
# 38                             NaN  2024-04-19      NaN         NaN
# 32                             NaN  2024-04-18      NaN         NaN
# 33                             NaN  2024-04-18      NaN         NaN
# 34                             NaN  2024-04-18      NaN         NaN
# 37                             NaN  2024-04-18      NaN         NaN
# 39                             NaN  2024-04-18      NaN         NaN
# 31                             NaN  2024-03-25      NaN         NaN
# 12                        fulltime  2024-04-22   hourly       15.00
# 13                             NaN  2024-04-21      NaN         NaN
# 14                             NaN  2024-04-21      NaN         NaN
# 16                        fulltime  2024-04-21   yearly    50000.00
# 17                        fulltime  2024-04-21   yearly    50000.00
# 18                             NaN  2024-04-21      NaN         NaN
# 11                             NaN  2024-04-19   hourly       16.00
# 10                             NaN  2024-04-18      NaN         NaN
# 15                             NaN  2024-04-18      NaN         NaN
# 19                             NaN  2024-04-11   hourly      147.00
#
#     max_amount currency is_remote                    emails  \
# 20         NaN      NaN     False                       NaN
# 25       17.00      USD      True                       NaN
# 28   100000.00      USD      True                       NaN
# 26   105000.00      USD     False            HR@85SIXTY.com
# 24   130000.00      USD      True                       NaN
# 29       45.00      USD      True                       NaN
# 21         NaN      NaN      True                       NaN
# 27   125000.00      USD      True                       NaN
# 22    92500.00      USD      True      careers@ellisdab.com
# 23   212304.00      USD      True                       NaN
# 0     20000.00      USD      True                       NaN
# 1          NaN      NaN      True                       NaN
# 2          NaN      USD      True                       NaN
# 4        17.36      USD      True                       NaN
# 6          NaN      NaN      True                       NaN
# 9    143000.00      USD      True                       NaN
# 5          NaN      USD      True  alyssa@workflowqueen.com
# 3    104900.00      USD      True  recruitingUS@sunlife.com
# 8          NaN      USD      True                       NaN
# 7          NaN      NaN      True                       NaN
# 36         NaN      NaN       NaN                       NaN
# 30         NaN      NaN       NaN                       NaN
# 35         NaN      NaN       NaN                       NaN
# 38         NaN      NaN       NaN                       NaN
# 32         NaN      NaN       NaN                       NaN
# 33         NaN      NaN       NaN                       NaN
# 34         NaN      NaN       NaN                       NaN
# 37         NaN      NaN       NaN                       NaN
# 39         NaN      NaN       NaN                       NaN
# 31         NaN      NaN       NaN                       NaN
# 12       18.00      USD       NaN                       NaN
# 13         NaN      NaN       NaN                       NaN
# 14         NaN      NaN       NaN                       NaN
# 16    60000.00      USD       NaN                       NaN
# 17    60000.00      USD       NaN                       NaN
# 18         NaN      NaN       NaN                       NaN
# 11       28.00      USD       NaN                       NaN
# 10         NaN      NaN       NaN                       NaN
# 15         NaN      NaN       NaN                       NaN
# 19      205.00      USD       NaN                       NaN
#
#                                           description  \
# 20  Our construction company is an Inc. 5,000 Busi...
# 25  **About MVSI:** \n\nMVSI is a market leading c...
# 28  **Why ITinfra?**\n\n* Small, growing, dynamic ...
# 26  Remote, US-based  \n**Overview:**  \nFor over ...
# 24  **P3 Adaptive is seeking qualified candidates ...
# 29  Inspira's mission is to democratize access to ...
# 21  Ready to take a different path? Passionate abo...
# 27  **Job description**\n\nIf you are looking for ...
# 22  **Ellis and Company** is on a mission to trans...
# 23  We're looking for our next High Ticket Closer ...
# 0   ***ARE YOU SEEKING YOUR NEXT INCOME OPPORTUNIT...
# 1   **Who We Are**\n\nNuScienta is a trailblazing ...
# 2   **Insurance Claims Attorney – Municipal Risk**...
# 4   **About MVSI:** \n\nMVSI is a market leading c...
# 6   **Who We Are**\n\nWe are a diverse firm with s...
# 9   **Join Our Expanding Sales Team!**\n\nAre you ...
# 5   **WE’RE HIRING!**\n\n**Executive Assistant to ...
# 3   You are as unique as your background, experien...
# 8   Extended Year Services for Middle School\n  \n...
# 7   Honu Services, Inc is seeking an experienced a...
# 36                                                NaN
# 30                                                NaN
# 35                                                NaN
# 38                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 37                                                NaN
# 39                                                NaN
# 31                                                NaN
# 12  **Full job description**\n\nJob Overview:\n\nW...
# 13  Ready to dive into the Sales realm?Join our vi...
# 14  Are you on the hunt for your next Sales opport...
# 16  1099 Job\n\n**Position summary**\n\nAmerican I...
# 17  1099 Job\n\n**Position summary**\n\nAmerican I...
# 18  Are you looking for your next opportunity in S...
# 11  If you are located within Mountain OR Pacific ...
# 10  CHS Inc. is a leading global agribusiness owne...
# 15  TITLE : Sr Project Manager LOCATION : Maryland...
# 19  Remote Licensed Psychiatric Nurse Practitioner...
#
#                                           company_url  \
# 20                                                NaN
# 25                                                NaN
# 28                                                NaN
# 26  https://www.glassdoor.com/Overview/W-EI_IE9429...
# 24  https://www.glassdoor.com/Overview/W-EI_IE6748...
# 29                                                NaN
# 21  https://www.glassdoor.com/Overview/W-EI_IE1982...
# 27                                                NaN
# 22                                                NaN
# 23                                                NaN
# 0   https://www.indeed.com/cmp/Lone-Star-Enterpris...
# 1        https://www.indeed.com/cmp/Data-Products-LLC
# 2   https://www.indeed.com/cmp/Tokio-Marine-Hcc---...
# 4             https://www.indeed.com/cmp/Mvsi-Onboard
# 6        https://www.indeed.com/cmp/Data-Products-LLC
# 9        https://www.indeed.com/cmp/The-Premier-Group
# 5           https://www.indeed.com/cmp/Workflow-Queen
# 3               https://www.indeed.com/cmp/Sun-Life-1
# 8   https://www.indeed.com/cmp/South-Central-Calho...
# 7             https://www.indeed.com/cmp/Na-Oiwi-Kane
# 36  https://www.linkedin.com/company/the-flex-company
# 30  https://www.linkedin.com/company/dreamscape-de...
# 35  https://www.linkedin.com/company/historic-hide...
# 38            https://www.linkedin.com/company/zillow
# 32      https://www.linkedin.com/company/loop-returns
# 33     https://www.linkedin.com/company/voyage-canvas
# 34     https://www.linkedin.com/company/voyage-canvas
# 37     https://www.linkedin.com/company/voyage-canvas
# 39  https://www.linkedin.com/company/wanderluxe-es...
# 31            https://www.linkedin.com/company/nogood
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 11                                                NaN
# 10                                                NaN
# 15                                                NaN
# 19                                                NaN
#
#                                 company_url_direct  \
# 20                                             NaN
# 25                                             NaN
# 28                                             NaN
# 26                                             NaN
# 24                                             NaN
# 29                                             NaN
# 21                                             NaN
# 27                                             NaN
# 22                                             NaN
# 23                                             NaN
# 0   https://www.wealthprotector.net/wealthbuilding
# 1                                              NaN
# 2                                              NaN
# 4                                              NaN
# 6                                              NaN
# 9                                              NaN
# 5                                              NaN
# 3                          https://www.sunlife.com
# 8                                              NaN
# 7                                              NaN
# 36                                             NaN
# 30                                             NaN
# 35                                             NaN
# 38                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 37                                             NaN
# 39                                             NaN
# 31                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 11                                             NaN
# 10                                             NaN
# 15                                             NaN
# 19                                             NaN
#
#                         company_addresses company_industry  \
# 20                                    NaN             None
# 25                                    NaN             None
# 28                                    NaN             None
# 26                                    NaN             None
# 24                                    NaN             None
# 29                                    NaN             None
# 21                                    NaN             None
# 27                                    NaN             None
# 22                                    NaN             None
# 23                                    NaN             None
# 0   2591 Dallas Pkwy\r\nFrisco, Texas USA             None
# 1                                     NaN             None
# 2                                     NaN             None
# 4                                     NaN             None
# 6                                     NaN             None
# 9                                     NaN             None
# 5                                     NaN             None
# 3                             Toronto, ON             None
# 8                                     NaN             None
# 7                                     NaN             None
# 36                                    NaN             None
# 30                                    NaN             None
# 35                                    NaN             None
# 38                                    NaN             None
# 32                                    NaN             None
# 33                                    NaN             None
# 34                                    NaN             None
# 37                                    NaN             None
# 39                                    NaN             None
# 31                                    NaN             None
# 12                                    NaN             None
# 13                                    NaN             None
# 14                                    NaN             None
# 16                                    NaN             None
# 17                                    NaN             None
# 18                                    NaN             None
# 11                                    NaN             None
# 10                                    NaN             None
# 15                                    NaN             None
# 19                                    NaN             None
#
#    company_num_employees   company_revenue company_description  \
# 20                   NaN               NaN                 NaN
# 25                   NaN               NaN                 NaN
# 28                   NaN               NaN                 NaN
# 26                   NaN               NaN                 NaN
# 24                   NaN               NaN                 NaN
# 29                   NaN               NaN                 NaN
# 21                   NaN               NaN                 NaN
# 27                   NaN               NaN                 NaN
# 22                   NaN               NaN                 NaN
# 23                   NaN               NaN                 NaN
# 0                10,000+  $1M to $5M (USD)
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 4                    NaN               NaN                 NaN
# 6                    NaN               NaN                 NaN
# 9                    NaN               NaN                 NaN
# 5                    NaN               NaN                 NaN
# 3                10,000+  $1B to $5B (USD)
# 8                    NaN               NaN                 NaN
# 7                    NaN               NaN                 NaN
# 36                   NaN               NaN                 NaN
# 30                   NaN               NaN                 NaN
# 35                   NaN               NaN                 NaN
# 38                   NaN               NaN                 NaN
# 32                   NaN               NaN                 NaN
# 33                   NaN               NaN                 NaN
# 34                   NaN               NaN                 NaN
# 37                   NaN               NaN                 NaN
# 39                   NaN               NaN                 NaN
# 31                   NaN               NaN                 NaN
# 12                   NaN               NaN                 NaN
# 13                   NaN               NaN                 NaN
# 14                   NaN               NaN                 NaN
# 16                   NaN               NaN                 NaN
# 17                   NaN               NaN                 NaN
# 18                   NaN               NaN                 NaN
# 11                   NaN               NaN                 NaN
# 10                   NaN               NaN                 NaN
# 15                   NaN               NaN                 NaN
# 19                   NaN               NaN                 NaN
#
#                                        logo_photo_url  \
# 20                                                NaN
# 25                                                NaN
# 28                                                NaN
# 26                                                NaN
# 24                                                NaN
# 29                                                NaN
# 21                                                NaN
# 27                                                NaN
# 22                                                NaN
# 23                                                NaN
# 0   https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 6                                                 NaN
# 9                                                 NaN
# 5                                                 NaN
# 3   https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 8                                                 NaN
# 7                                                 NaN
# 36                                                NaN
# 30                                                NaN
# 35                                                NaN
# 38                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 37                                                NaN
# 39                                                NaN
# 31                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 11                                                NaN
# 10                                                NaN
# 15                                                NaN
# 19                                                NaN
#
#                                      banner_photo_url      ceo_name  \
# 20                                                NaN           NaN
# 25                                                NaN           NaN
# 28                                                NaN           NaN
# 26                                                NaN           NaN
# 24                                                NaN           NaN
# 29                                                NaN           NaN
# 21                                                NaN           NaN
# 27                                                NaN           NaN
# 22                                                NaN           NaN
# 23                                                NaN           NaN
# 0   https://d2q79iu7y748jz.cloudfront.net/s/_heade...           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 4                                                 NaN           NaN
# 6                                                 NaN           NaN
# 9                                                 NaN           NaN
# 5                                                 NaN           NaN
# 3   https://d2q79iu7y748jz.cloudfront.net/s/_heade...  Kevin Strain
# 8                                                 NaN           NaN
# 7                                                 NaN           NaN
# 36                                                NaN           NaN
# 30                                                NaN           NaN
# 35                                                NaN           NaN
# 38                                                NaN           NaN
# 32                                                NaN           NaN
# 33                                                NaN           NaN
# 34                                                NaN           NaN
# 37                                                NaN           NaN
# 39                                                NaN           NaN
# 31                                                NaN           NaN
# 12                                                NaN           NaN
# 13                                                NaN           NaN
# 14                                                NaN           NaN
# 16                                                NaN           NaN
# 17                                                NaN           NaN
# 18                                                NaN           NaN
# 11                                                NaN           NaN
# 10                                                NaN           NaN
# 15                                                NaN           NaN
# 19                                                NaN           NaN
#
#                                         ceo_photo_url
# 20                                                NaN
# 25                                                NaN
# 28                                                NaN
# 26                                                NaN
# 24                                                NaN
# 29                                                NaN
# 21                                                NaN
# 27                                                NaN
# 22                                                NaN
# 23                                                NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 6                                                 NaN
# 9                                                 NaN
# 5                                                 NaN
# 3   https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...
# 8                                                 NaN
# 7                                                 NaN
# 36                                                NaN
# 30                                                NaN
# 35                                                NaN
# 38                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 37                                                NaN
# 39                                                NaN
# 31                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 11                                                NaN
# 10                                                NaN
# 15                                                NaN
# 19                                                NaN
