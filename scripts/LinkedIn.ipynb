# %%
"""
Provides linkedin api-related code
"""

import json
import logging
import random
import uuid
from operator import itemgetter
from time import sleep
from urllib.parse import urlencode

from linkedin_api.client import Client
from linkedin_api.utils.helpers import (
    get_id_from_urn,
    get_urn_from_raw_update,
    get_list_posts_sorted_without_promoted,
    parse_list_raw_posts,
    parse_list_raw_urns,
    generate_trackingId,
    generate_trackingId_as_charString,
)

logger = logging.getLogger(__name__)


def default_evade():
    """
    A catch-all method to try and evade suspension from Linkedin.
    Currenly, just delays the request by a random (bounded) time
    """
    sleep(random.randint(2, 5))  # sleep a random duration to try and evade suspention


class Linkedin(object):
    """
    Class for accessing the LinkedIn API.

    :param username: Username of LinkedIn account.
    :type username: str
    :param password: Password of LinkedIn account.
    :type password: str
    """

    _MAX_POST_COUNT = 100  # max seems to be 100 posts per page
    _MAX_UPDATE_COUNT = 100  # max seems to be 100
    _MAX_SEARCH_COUNT = 49  # max seems to be 49, and min seems to be 2
    _MAX_REPEATED_REQUESTS = (
        200  # VERY conservative max requests count to avoid rate-limit
    )

    def __init__(
        self,
        username,
        password,
        *,
        authenticate=True,
        refresh_cookies=False,
        debug=False,
        proxies={},
        cookies=None,
        cookies_dir=None,
    ):
        """Constructor method"""
        self.client = Client(
            refresh_cookies=refresh_cookies,
            debug=debug,
            proxies=proxies,
            cookies_dir=cookies_dir,
        )
        logging.basicConfig(level=logging.DEBUG if debug else logging.INFO)
        self.logger = logger

        if authenticate:
            if cookies:
                # If the cookies are expired, the API won't work anymore since
                # `username` and `password` are not used at all in this case.
                self.client._set_session_cookies(cookies)
            else:
                self.client.authenticate(username, password)

    def _fetch(self, uri, evade=default_evade, base_request=False, **kwargs):
        """GET request to Linkedin API"""
        evade()

        url = f"{self.client.API_BASE_URL if not base_request else self.client.LINKEDIN_BASE_URL}{uri}"
        return self.client.session.get(url, **kwargs)

    def _cookies(self):
        """Return client cookies"""
        return self.client.cookies

    def _headers(self):
        """Return client cookies"""
        return self.client.REQUEST_HEADERS

    def _post(self, uri, evade=default_evade, base_request=False, **kwargs):
        """POST request to Linkedin API"""
        evade()

        url = f"{self.client.API_BASE_URL if not base_request else self.client.LINKEDIN_BASE_URL}{uri}"
        return self.client.session.post(url, **kwargs)

    def get_profile_posts(self, public_id=None, urn_id=None, post_count=10):
        """
        get_profile_posts: Get profile posts

        :param public_id: LinkedIn public ID for a profile
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str, optional
        :param post_count: Number of posts to fetch
        :type post_count: int, optional
        :return: List of posts
        :rtype: list
        """
        url_params = {
            "count": min(post_count, self._MAX_POST_COUNT),
            "start": 0,
            "q": "memberShareFeed",
            "moduleKey": "member-shares:phone",
            "includeLongTermHistory": True,
        }
        if urn_id:
            profile_urn = f"urn:li:fsd_profile:{urn_id}"
        else:
            profile = self.get_profile(public_id=public_id)
            profile_urn = profile["profile_urn"].replace(
                "fs_miniProfile", "fsd_profile"
            )
        url_params["profileUrn"] = profile_urn
        url = f"/identity/profileUpdatesV2"
        res = self._fetch(url, params=url_params)
        data = res.json()
        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data["message"]))
            return {}
        while data and data["metadata"]["paginationToken"] != "":
            if len(data["elements"]) >= post_count:
                break
            pagination_token = data["metadata"]["paginationToken"]
            url_params["start"] = url_params["start"] + self._MAX_POST_COUNT
            url_params["paginationToken"] = pagination_token
            res = self._fetch(url, params=url_params)
            data["metadata"] = res.json()["metadata"]
            data["elements"] = data["elements"] + res.json()["elements"]
            data["paging"] = res.json()["paging"]
        return data["elements"]

    def get_post_comments(self, post_urn, comment_count=100):
        """
        get_post_comments: Get post comments

        :param post_urn: Post URN
        :type post_urn: str
        :param comment_count: Number of comments to fetch
        :type comment_count: int, optional
        :return: List of post comments
        :rtype: list
        """
        url_params = {
            "count": min(comment_count, self._MAX_POST_COUNT),
            "start": 0,
            "q": "comments",
            "sortOrder": "RELEVANCE",
        }
        url = f"/feed/comments"
        url_params["updateId"] = "activity:" + post_urn
        res = self._fetch(url, params=url_params)
        data = res.json()
        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data["status"]))
            return {}
        while data and data["metadata"]["paginationToken"] != "":
            if len(data["elements"]) >= comment_count:
                break
            pagination_token = data["metadata"]["paginationToken"]
            url_params["start"] = url_params["start"] + self._MAX_POST_COUNT
            url_params["count"] = self._MAX_POST_COUNT
            url_params["paginationToken"] = pagination_token
            res = self._fetch(url, params=url_params)
            if res.json() and "status" in res.json() and res.json()["status"] != 200:
                self.logger.info("request failed: {}".format(data["status"]))
                return {}
            data["metadata"] = res.json()["metadata"]
            """ When the number of comments exceed total available 
            comments, the api starts returning an empty list of elements"""
            if res.json()["elements"] and len(res.json()["elements"]) == 0:
                break
            if data["elements"] and len(res.json()["elements"]) == 0:
                break
            data["elements"] = data["elements"] + res.json()["elements"]
            data["paging"] = res.json()["paging"]
        return data["elements"]

    def search(self, params, limit=-1, offset=0):
        """Perform a LinkedIn search.

        :param params: Search parameters (see code)
        :type params: dict
        :param limit: Maximum length of the returned list, defaults to -1 (no limit)
        :type limit: int, optional
        :param offset: Index to start searching from
        :type offset: int, optional


        :return: List of search results
        :rtype: list
        """
        count = Linkedin._MAX_SEARCH_COUNT
        if limit is None:
            limit = -1

        results = []
        while True:
            # when we're close to the limit, only fetch what we need to
            if limit > -1 and limit - len(results) < count:
                count = limit - len(results)
            default_params = {
                "count": str(count),
                "filters": "List()",
                "origin": "GLOBAL_SEARCH_HEADER",
                "q": "all",
                "start": len(results) + offset,
                "queryContext": "List(spellCorrectionEnabled->true,relatedSearchesEnabled->true,kcardTypes->PROFILE|COMPANY)",
                "includeWebMetadata": "true",
            }
            default_params.update(params)

            keywords = (
                f"keywords:{default_params['keywords']},"
                if "keywords" in default_params
                else ""
            )

            res = self._fetch(
                f"/graphql?variables=(start:{default_params['start']},origin:{default_params['origin']},"
                f"query:("
                f"{keywords}"
                f"flagshipSearchIntent:SEARCH_SRP,"
                f"queryParameters:{default_params['filters']},"
                f"includeFiltersInResponse:false))&queryId=voyagerSearchDashClusters"
                f".b0928897b71bd00a5a7291755dcd64f0"
            )
            data = res.json()

            data_clusters = data.get("data", []).get("searchDashClustersByAll", [])

            if not data_clusters:
                return []

            if (
                not data_clusters.get("_type", [])
                == "com.linkedin.restli.common.CollectionResponse"
            ):
                return []

            new_elements = []
            for it in data_clusters.get("elements", []):
                if (
                    not it.get("_type", [])
                    == "com.linkedin.voyager.dash.search.SearchClusterViewModel"
                ):
                    continue

                for el in it.get("items", []):
                    if (
                        not el.get("_type", [])
                        == "com.linkedin.voyager.dash.search.SearchItem"
                    ):
                        continue

                    e = el.get("item", []).get("entityResult", [])
                    if not e:
                        continue
                    if (
                        not e.get("_type", [])
                        == "com.linkedin.voyager.dash.search.EntityResultViewModel"
                    ):
                        continue
                    new_elements.append(e)

            results.extend(new_elements)

            # break the loop if we're done searching
            # NOTE: we could also check for the `total` returned in the response.
            # This is in data["data"]["paging"]["total"]
            if (
                (-1 < limit <= len(results))  # if our results exceed set limit
                or len(results) / count >= Linkedin._MAX_REPEATED_REQUESTS
            ) or len(new_elements) == 0:
                break

            self.logger.debug(f"results grew to {len(results)}")

        return results

    def search_people(
        self,
        keywords=None,
        connection_of=None,
        network_depths=None,
        current_company=None,
        past_companies=None,
        nonprofit_interests=None,
        profile_languages=None,
        regions=None,
        industries=None,
        schools=None,
        contact_interests=None,
        service_categories=None,
        include_private_profiles=False,  # profiles without a public id, "Linkedin Member"
        # Keywords filter
        keyword_first_name=None,
        keyword_last_name=None,
        # `keyword_title` and `title` are the same. We kept `title` for backward compatibility. Please only use one of them.
        keyword_title=None,
        keyword_company=None,
        keyword_school=None,
        network_depth=None,  # DEPRECATED - use network_depths
        title=None,  # DEPRECATED - use keyword_title
        **kwargs,
    ):
        """Perform a LinkedIn search for people.

        :param keywords: Keywords to search on
        :type keywords: str, optional
        :param current_company: A list of company URN IDs (str)
        :type current_company: list, optional
        :param past_companies: A list of company URN IDs (str)
        :type past_companies: list, optional
        :param regions: A list of geo URN IDs (str)
        :type regions: list, optional
        :param industries: A list of industry URN IDs (str)
        :type industries: list, optional
        :param schools: A list of school URN IDs (str)
        :type schools: list, optional
        :param profile_languages: A list of 2-letter language codes (str)
        :type profile_languages: list, optional
        :param contact_interests: A list containing one or both of "proBono" and "boardMember"
        :type contact_interests: list, optional
        :param service_categories: A list of service category URN IDs (str)
        :type service_categories: list, optional
        :param network_depth: Deprecated, use `network_depths`. One of "F", "S" and "O" (first, second and third+ respectively)
        :type network_depth: str, optional
        :param network_depths: A list containing one or many of "F", "S" and "O" (first, second and third+ respectively)
        :type network_depths: list, optional
        :param include_private_profiles: Include private profiles in search results. If False, only public profiles are included. Defaults to False
        :type include_private_profiles: boolean, optional
        :param keyword_first_name: First name
        :type keyword_first_name: str, optional
        :param keyword_last_name: Last name
        :type keyword_last_name: str, optional
        :param keyword_title: Job title
        :type keyword_title: str, optional
        :param keyword_company: Company name
        :type keyword_company: str, optional
        :param keyword_school: School name
        :type keyword_school: str, optional
        :param connection_of: Connection of LinkedIn user, given by profile URN ID
        :type connection_of: str, optional
        :param limit: Maximum length of the returned list, defaults to -1 (no limit)
        :type limit: int, optional

        :return: List of profiles (minimal data only)
        :rtype: list
        """
        filters = ["(key:resultType,value:List(PEOPLE))"]
        if connection_of:
            filters.append(f"(key:connectionOf,value:List({connection_of}))")
        if network_depths:
            stringify = " | ".join(network_depths)
            filters.append(f"(key:network,value:List({stringify}))")
        elif network_depth:
            filters.append(f"(key:network,value:List({network_depth}))")
        if regions:
            stringify = " | ".join(regions)
            filters.append(f"(key:geoUrn,value:List({stringify}))")
        if industries:
            stringify = " | ".join(industries)
            filters.append(f"(key:industry,value:List({stringify}))")
        if current_company:
            stringify = " | ".join(current_company)
            filters.append(f"(key:currentCompany,value:List({stringify}))")
        if past_companies:
            stringify = " | ".join(past_companies)
            filters.append(f"(key:pastCompany,value:List({stringify}))")
        if profile_languages:
            stringify = " | ".join(profile_languages)
            filters.append(f"(key:profileLanguage,value:List({stringify}))")
        if nonprofit_interests:
            stringify = " | ".join(nonprofit_interests)
            filters.append(f"(key:nonprofitInterest,value:List({stringify}))")
        if schools:
            stringify = " | ".join(schools)
            filters.append(f"(key:schools,value:List({stringify}))")
        if service_categories:
            stringify = " | ".join(service_categories)
            filters.append(f"(key:serviceCategory,value:List({stringify}))")
        # `Keywords` filter
        keyword_title = keyword_title if keyword_title else title
        if keyword_first_name:
            filters.append(f"(key:firstName,value:List({keyword_first_name}))")
        if keyword_last_name:
            filters.append(f"(key:lastName,value:List({keyword_last_name}))")
        if keyword_title:
            filters.append(f"(key:title,value:List({keyword_title}))")
        if keyword_company:
            filters.append(f"(key:company,value:List({keyword_company}))")
        if keyword_school:
            filters.append(f"(key:school,value:List({keyword_school}))")

        params = {"filters": "List({})".format(",".join(filters))}

        if keywords:
            params["keywords"] = keywords

        data = self.search(params, **kwargs)

        results = []
        for item in data:
            if (
                not include_private_profiles
                and (item.get("entityCustomTrackingInfo") or {}).get(
                    "memberDistance", None
                )
                == "OUT_OF_NETWORK"
            ):
                continue
            results.append(
                {
                    "urn_id": get_id_from_urn(
                        get_urn_from_raw_update(item.get("entityUrn", None))
                    ),
                    "distance": (item.get("entityCustomTrackingInfo") or {}).get(
                        "memberDistance", None
                    ),
                    "jobtitle": (item.get("primarySubtitle") or {}).get("text", None),
                    "location": (item.get("secondarySubtitle") or {}).get("text", None),
                    "name": (item.get("title") or {}).get("text", None),
                }
            )

        return results

    def search_companies(self, keywords=None, **kwargs):
        """Perform a LinkedIn search for companies.

        :param keywords: A list of search keywords (str)
        :type keywords: list, optional

        :return: List of companies
        :rtype: list
        """
        filters = ["(key:resultType,value:List(COMPANIES))"]

        params = {
            "filters": "List({})".format(",".join(filters)),
            "queryContext": "List(spellCorrectionEnabled->true)",
        }

        if keywords:
            params["keywords"] = keywords

        data = self.search(params, **kwargs)

        results = []
        for item in data:
            if "company" not in item.get("trackingUrn"):
                continue
            results.append(
                {
                    "urn_id": get_id_from_urn(item.get("trackingUrn", None)),
                    "name": (item.get("title") or {}).get("text", None),
                    "headline": (item.get("primarySubtitle") or {}).get("text", None),
                    "subline": (item.get("secondarySubtitle") or {}).get("text", None),
                }
            )

        return results

    def search_jobs(
        self,
        keywords=None,
        companies=None,
        experience=None,
        job_type=None,
        job_title=None,
        industries=None,
        location_name=None,
        remote=None,
        listed_at=24 * 60 * 60,
        distance=None,
        limit=-1,
        offset=0,
        **kwargs,
    ):
        """Perform a LinkedIn search for jobs.

        :param keywords: Search keywords (str)
        :type keywords: str, optional
        :param companies: A list of company URN IDs (str)
        :type companies: list, optional
        :param experience: A list of experience levels, one or many of "1", "2", "3", "4", "5" and "6" (internship, entry level, associate, mid-senior level, director and executive, respectively)
        :type experience: list, optional
        :param job_type:  A list of job types , one or many of "F", "C", "P", "T", "I", "V", "O" (full-time, contract, part-time, temporary, internship, volunteer and "other", respectively)
        :type job_type: list, optional
        :param job_title: A list of title URN IDs (str)
        :type job_title: list, optional
        :param industries: A list of industry URN IDs (str)
        :type industries: list, optional
        :param location_name: Name of the location to search within. Example: "Kyiv City, Ukraine"
        :type location_name: str, optional
        :param remote: Filter for remote jobs, onsite or hybrid. onsite:"1", remote:"2", hybrid:"3"
        :type remote: list, optional
        :param listed_at: maximum number of seconds passed since job posting. 86400 will filter job postings posted in last 24 hours.
        :type listed_at: int/str, optional. Default value is equal to 24 hours.
        :param distance: maximum distance from location in miles
        :type distance: int/str, optional. If not specified, None or 0, the default value of 25 miles applied.
        :param limit: maximum number of results obtained from API queries. -1 means maximum which is defined by constants and is equal to 1000 now.
        :type limit: int, optional, default -1
        :param offset: indicates how many search results shall be skipped
        :type offset: int, optional
        :return: List of jobs
        :rtype: list
        """
        count = Linkedin._MAX_SEARCH_COUNT
        if limit is None:
            limit = -1

        query = {"origin": "JOB_SEARCH_PAGE_QUERY_EXPANSION"}
        if keywords:
            query["keywords"] = "KEYWORD_PLACEHOLDER"
        if location_name:
            query["locationFallback"] = "LOCATION_PLACEHOLDER"

        # In selectedFilters()
        query["selectedFilters"] = {}
        if companies:
            query["selectedFilters"]["company"] = f"List({','.join(companies)})"
        if experience:
            query["selectedFilters"]["experience"] = f"List({','.join(experience)})"
        if job_type:
            query["selectedFilters"]["jobType"] = f"List({','.join(job_type)})"
        if job_title:
            query["selectedFilters"]["title"] = f"List({','.join(job_title)})"
        if industries:
            query["selectedFilters"]["industry"] = f"List({','.join(industries)})"
        if distance:
            query["selectedFilters"]["distance"] = f"List({distance})"
        if remote:
            query["selectedFilters"]["workplaceType"] = f"List({','.join(remote)})"

        query["selectedFilters"]["timePostedRange"] = f"List(r{listed_at})"
        query["spellCorrectionEnabled"] = "true"

        # Query structure:
        # "(
        #    origin:JOB_SEARCH_PAGE_QUERY_EXPANSION,
        #    keywords:marketing%20manager,
        #    locationFallback:germany,
        #    selectedFilters:(
        #        distance:List(25),
        #        company:List(163253),
        #        salaryBucketV2:List(5),
        #        timePostedRange:List(r2592000),
        #        workplaceType:List(1)
        #    ),
        #    spellCorrectionEnabled:true
        #  )"

        query = (
            str(query)
            .replace(" ", "")
            .replace("'", "")
            .replace("KEYWORD_PLACEHOLDER", keywords or "")
            .replace("LOCATION_PLACEHOLDER", location_name or "")
            .replace("{", "(")
            .replace("}", ")")
        )
        results = []
        while True:
            # when we're close to the limit, only fetch what we need to
            if limit > -1 and limit - len(results) < count:
                count = limit - len(results)
            default_params = {
                "decorationId": "com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollection-174",
                "count": count,
                "q": "jobSearch",
                "query": query,
                "start": len(results) + offset,
            }

            res = self._fetch(
                f"/voyagerJobsDashJobCards?{urlencode(default_params, safe='(),:')}",
                headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
            )
            data = res.json()

            elements = data.get("included", [])
            new_data = [
                i
                for i in elements
                if i["$type"] == "com.linkedin.voyager.dash.jobs.JobPosting"
            ]
            # break the loop if we're done searching or no results returned
            if not new_data:
                break
            # NOTE: we could also check for the `total` returned in the response.
            # This is in data["data"]["paging"]["total"]
            results.extend(new_data)
            if (
                (-1 < limit <= len(results))  # if our results exceed set limit
                or len(results) / count >= Linkedin._MAX_REPEATED_REQUESTS
            ) or len(elements) == 0:
                break

            self.logger.debug(f"results grew to {len(results)}")

        return results

    def get_profile_contact_info(self, public_id=None, urn_id=None):
        """Fetch contact information for a given LinkedIn profile. Pass a [public_id] or a [urn_id].

        :param public_id: LinkedIn public ID for a profile
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str, optional

        :return: Contact data
        :rtype: dict
        """
        res = self._fetch(
            f"/identity/profiles/{public_id or urn_id}/profileContactInfo"
        )
        data = res.json()

        contact_info = {
            "email_address": data.get("emailAddress"),
            "websites": [],
            "twitter": data.get("twitterHandles"),
            "birthdate": data.get("birthDateOn"),
            "ims": data.get("ims"),
            "phone_numbers": data.get("phoneNumbers", []),
        }

        websites = data.get("websites", [])
        for item in websites:
            if "com.linkedin.voyager.identity.profile.StandardWebsite" in item["type"]:
                item["label"] = item["type"][
                    "com.linkedin.voyager.identity.profile.StandardWebsite"
                ]["category"]
            elif "" in item["type"]:
                item["label"] = item["type"][
                    "com.linkedin.voyager.identity.profile.CustomWebsite"
                ]["label"]

            del item["type"]

        contact_info["websites"] = websites

        return contact_info

    def get_profile_skills(self, public_id=None, urn_id=None):
        """Fetch the skills listed on a given LinkedIn profile.

        :param public_id: LinkedIn public ID for a profile
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str, optional


        :return: List of skill objects
        :rtype: list
        """
        params = {"count": 100, "start": 0}
        res = self._fetch(
            f"/identity/profiles/{public_id or urn_id}/skills", params=params
        )
        data = res.json()

        skills = data.get("elements", [])
        for item in skills:
            del item["entityUrn"]

        return skills

    def get_profile(self, public_id=None, urn_id=None):
        """Fetch data for a given LinkedIn profile.

        :param public_id: LinkedIn public ID for a profile
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str, optional

        :return: Profile data
        :rtype: dict
        """
        # NOTE this still works for now, but will probably eventually have to be converted to
        # https://www.linkedin.com/voyager/api/identity/profiles/ACoAAAKT9JQBsH7LwKaE9Myay9WcX8OVGuDq9Uw
        res = self._fetch(f"/identity/profiles/{public_id or urn_id}/profileView")

        data = res.json()
        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data["message"]))
            return {}

        # massage [profile] data
        profile = data["profile"]
        if "miniProfile" in profile:
            if "picture" in profile["miniProfile"]:
                profile["displayPictureUrl"] = profile["miniProfile"]["picture"][
                    "com.linkedin.common.VectorImage"
                ]["rootUrl"]

                images_data = profile["miniProfile"]["picture"][
                    "com.linkedin.common.VectorImage"
                ]["artifacts"]
                for img in images_data:
                    w, h, url_segment = itemgetter(
                        "width", "height", "fileIdentifyingUrlPathSegment"
                    )(img)
                    profile[f"img_{w}_{h}"] = url_segment

            profile["profile_id"] = get_id_from_urn(profile["miniProfile"]["entityUrn"])
            profile["profile_urn"] = profile["miniProfile"]["entityUrn"]
            profile["member_urn"] = profile["miniProfile"]["objectUrn"]
            profile["public_id"] = profile["miniProfile"]["publicIdentifier"]

            del profile["miniProfile"]

        del profile["defaultLocale"]
        del profile["supportedLocales"]
        del profile["versionTag"]
        del profile["showEducationOnProfileTopCard"]

        # massage [experience] data
        experience = data["positionView"]["elements"]
        for item in experience:
            if "company" in item and "miniCompany" in item["company"]:
                if "logo" in item["company"]["miniCompany"]:
                    logo = item["company"]["miniCompany"]["logo"].get(
                        "com.linkedin.common.VectorImage"
                    )
                    if logo:
                        item["companyLogoUrl"] = logo["rootUrl"]
                del item["company"]["miniCompany"]

        profile["experience"] = experience

        # massage [education] data
        education = data["educationView"]["elements"]
        for item in education:
            if "school" in item:
                if "logo" in item["school"]:
                    item["school"]["logoUrl"] = item["school"]["logo"][
                        "com.linkedin.common.VectorImage"
                    ]["rootUrl"]
                    del item["school"]["logo"]

        profile["education"] = education

        # massage [languages] data
        languages = data["languageView"]["elements"]
        for item in languages:
            del item["entityUrn"]
        profile["languages"] = languages

        # massage [publications] data
        publications = data["publicationView"]["elements"]
        for item in publications:
            del item["entityUrn"]
            for author in item.get("authors", []):
                del author["entityUrn"]
        profile["publications"] = publications

        # massage [certifications] data
        certifications = data["certificationView"]["elements"]
        for item in certifications:
            del item["entityUrn"]
        profile["certifications"] = certifications

        # massage [volunteer] data
        volunteer = data["volunteerExperienceView"]["elements"]
        for item in volunteer:
            del item["entityUrn"]
        profile["volunteer"] = volunteer

        # massage [honors] data
        honors = data["honorView"]["elements"]
        for item in honors:
            del item["entityUrn"]
        profile["honors"] = honors

        # massage [projects] data
        projects = data["projectView"]["elements"]
        for item in projects:
            del item["entityUrn"]
        profile["projects"] = projects
        # massage [skills] data
        skills = data["skillView"]["elements"]
        for item in skills:
            del item["entityUrn"]
        profile["skills"] = skills

        profile["urn_id"] = profile["entityUrn"].replace("urn:li:fs_profile:", "")

        return profile

    def get_profile_connections(self, urn_id):
        """Fetch first-degree connections for a given LinkedIn profile.

        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str

        :return: List of search results
        :rtype: list
        """
        return self.search_people(connection_of=urn_id, network_depth="F")

    def get_company_updates(
        self, public_id=None, urn_id=None, max_results=None, results=None
    ):
        """Fetch company updates (news activity) for a given LinkedIn company.

        :param public_id: LinkedIn public ID for a company
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a company
        :type urn_id: str, optional

        :return: List of company update objects
        :rtype: list
        """

        if results is None:
            results = []

        params = {
            "companyUniversalName": {public_id or urn_id},
            "q": "companyFeedByUniversalName",
            "moduleKey": "member-share",
            "count": Linkedin._MAX_UPDATE_COUNT,
            "start": len(results),
        }

        res = self._fetch(f"/feed/updates", params=params)

        data = res.json()

        if (
            len(data["elements"]) == 0
            or (max_results is not None and len(results) >= max_results)
            or (
                max_results is not None
                and len(results) / max_results >= Linkedin._MAX_REPEATED_REQUESTS
            )
        ):
            return results

        results.extend(data["elements"])
        self.logger.debug(f"results grew: {len(results)}")

        return self.get_company_updates(
            public_id=public_id,
            urn_id=urn_id,
            results=results,
            max_results=max_results,
        )

    def get_profile_updates(
        self, public_id=None, urn_id=None, max_results=None, results=None
    ):
        """Fetch profile updates (newsfeed activity) for a given LinkedIn profile.

        :param public_id: LinkedIn public ID for a profile
        :type public_id: str, optional
        :param urn_id: LinkedIn URN ID for a profile
        :type urn_id: str, optional

        :return: List of profile update objects
        :rtype: list
        """

        if results is None:
            results = []

        params = {
            "profileId": {public_id or urn_id},
            "q": "memberShareFeed",
            "moduleKey": "member-share",
            "count": Linkedin._MAX_UPDATE_COUNT,
            "start": len(results),
        }

        res = self._fetch(f"/feed/updates", params=params)

        data = res.json()

        if (
            len(data["elements"]) == 0
            or (max_results is not None and len(results) >= max_results)
            or (
                max_results is not None
                and len(results) / max_results >= Linkedin._MAX_REPEATED_REQUESTS
            )
        ):
            return results

        results.extend(data["elements"])
        self.logger.debug(f"results grew: {len(results)}")

        return self.get_profile_updates(
            public_id=public_id,
            urn_id=urn_id,
            results=results,
            max_results=max_results,
        )

    def get_current_profile_views(self):
        """Get profile view statistics, including chart data.

        :return: Profile view data
        :rtype: dict
        """
        res = self._fetch(f"/identity/wvmpCards")

        data = res.json()

        return data["elements"][0]["value"][
            "com.linkedin.voyager.identity.me.wvmpOverview.WvmpViewersCard"
        ]["insightCards"][0]["value"][
            "com.linkedin.voyager.identity.me.wvmpOverview.WvmpSummaryInsightCard"
        ][
            "numViews"
        ]

    def get_school(self, public_id):
        """Fetch data about a given LinkedIn school.

        :param public_id: LinkedIn public ID for a school
        :type public_id: str

        :return: School data
        :rtype: dict
        """
        params = {
            "decorationId": "com.linkedin.voyager.deco.organization.web.WebFullCompanyMain-12",
            "q": "universalName",
            "universalName": public_id,
        }

        res = self._fetch(f"/organization/companies?{urlencode(params)}")

        data = res.json()

        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data))
            return {}

        school = data["elements"][0]

        return school

    def get_company(self, public_id):
        """Fetch data about a given LinkedIn company.

        :param public_id: LinkedIn public ID for a company
        :type public_id: str

        :return: Company data
        :rtype: dict
        """
        params = {
            "decorationId": "com.linkedin.voyager.deco.organization.web.WebFullCompanyMain-12",
            "q": "universalName",
            "universalName": public_id,
        }

        res = self._fetch(f"/organization/companies", params=params)

        data = res.json()

        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data["message"]))
            return {}

        company = data["elements"][0]

        return company

    def get_conversation_details(self, profile_urn_id):
        """Fetch conversation (message thread) details for a given LinkedIn profile.

        :param profile_urn_id: LinkedIn URN ID for a profile
        :type profile_urn_id: str

        :return: Conversation data
        :rtype: dict
        """
        # passing `params` doesn't work properly, think it's to do with List().
        # Might be a bug in `requests`?
        res = self._fetch(
            f"/messaging/conversations?\
            keyVersion=LEGACY_INBOX&q=participants&recipients=List({profile_urn_id})"
        )

        data = res.json()

        if data["elements"] == []:
            return {}

        item = data["elements"][0]
        item["id"] = get_id_from_urn(item["entityUrn"])

        return item

    def get_conversations(self):
        """Fetch list of conversations the user is in.

        :return: List of conversations
        :rtype: list
        """
        params = {"keyVersion": "LEGACY_INBOX"}

        res = self._fetch(f"/messaging/conversations", params=params)

        return res.json()

    def get_conversation(self, conversation_urn_id):
        """Fetch data about a given conversation.

        :param conversation_urn_id: LinkedIn URN ID for a conversation
        :type conversation_urn_id: str

        :return: Conversation data
        :rtype: dict
        """
        res = self._fetch(f"/messaging/conversations/{conversation_urn_id}/events")

        return res.json()

    def send_message(self, message_body, conversation_urn_id=None, recipients=None):
        """Send a message to a given conversation.

        :param message_body: Message text to send
        :type message_body: str
        :param conversation_urn_id: LinkedIn URN ID for a conversation
        :type conversation_urn_id: str, optional
        :param recipients: List of profile urn id's
        :type recipients: list, optional

        :return: Error state. If True, an error occured.
        :rtype: boolean
        """
        params = {"action": "create"}

        if not (conversation_urn_id or recipients):
            self.logger.debug("Must provide [conversation_urn_id] or [recipients].")
            return True

        message_event = {
            "eventCreate": {
                "originToken": str(uuid.uuid4()),
                "value": {
                    "com.linkedin.voyager.messaging.create.MessageCreate": {
                        "attributedBody": {
                            "text": message_body,
                            "attributes": [],
                        },
                        "attachments": [],
                    }
                },
                "trackingId": generate_trackingId_as_charString(),
            },
            "dedupeByClientGeneratedToken": False,
        }

        if conversation_urn_id and not recipients:
            res = self._post(
                f"/messaging/conversations/{conversation_urn_id}/events",
                params=params,
                data=json.dumps(message_event),
            )
        elif recipients and not conversation_urn_id:
            message_event["recipients"] = recipients
            message_event["subtype"] = "MEMBER_TO_MEMBER"
            payload = {
                "keyVersion": "LEGACY_INBOX",
                "conversationCreate": message_event,
            }
            res = self._post(
                f"/messaging/conversations",
                params=params,
                data=json.dumps(payload),
            )

        return res.status_code != 201

    def mark_conversation_as_seen(self, conversation_urn_id):
        """Send 'seen' to a given conversation.

        :param conversation_urn_id: LinkedIn URN ID for a conversation
        :type conversation_urn_id: str

        :return: Error state. If True, an error occured.
        :rtype: boolean
        """
        payload = json.dumps({"patch": {"$set": {"read": True}}})

        res = self._post(
            f"/messaging/conversations/{conversation_urn_id}", data=payload
        )

        return res.status_code != 200

    def get_user_profile(self, use_cache=True):
        """Get the current user profile. If not cached, a network request will be fired.

        :return: Profile data for currently logged in user
        :rtype: dict
        """
        me_profile = self.client.metadata.get("me")
        if not self.client.metadata.get("me") or not use_cache:
            res = self._fetch(f"/me")
            me_profile = res.json()
            # cache profile
            self.client.metadata["me"] = me_profile

        return me_profile

    def get_invitations(self, start=0, limit=3):
        """Fetch connection invitations for the currently logged in user.

        :param start: How much to offset results by
        :type start: int
        :param limit: Maximum amount of invitations to return
        :type limit: int

        :return: List of invitation objects
        :rtype: list
        """
        params = {
            "start": start,
            "count": limit,
            "includeInsights": True,
            "q": "receivedInvitation",
        }

        res = self._fetch(
            "/relationships/invitationViews",
            params=params,
        )

        if res.status_code != 200:
            return []

        response_payload = res.json()
        return [element["invitation"] for element in response_payload["elements"]]

    def reply_invitation(
        self, invitation_entity_urn, invitation_shared_secret, action="accept"
    ):
        """Respond to a connection invitation. By default, accept the invitation.

        :param invitation_entity_urn: URN ID of the invitation
        :type invitation_entity_urn: int
        :param invitation_shared_secret: Shared secret of invitation
        :type invitation_shared_secret: str
        :param action: "accept" or "reject". Defaults to "accept"
        :type action: str, optional

        :return: Success state. True if successful
        :rtype: boolean
        """
        invitation_id = get_id_from_urn(invitation_entity_urn)
        params = {"action": action}
        payload = json.dumps(
            {
                "invitationId": invitation_id,
                "invitationSharedSecret": invitation_shared_secret,
                "isGenericInvitation": False,
            }
        )

        res = self._post(
            f"/relationships/invitations/{invitation_id}",
            params=params,
            data=payload,
        )

        return res.status_code == 200

    def add_connection(self, profile_public_id, message="", profile_urn=None):
        """Add a given profile id as a connection.

        :param profile_public_id: public ID of a LinkedIn profile
        :type profile_public_id: str
        :param message: message to send along with connection request
        :type profile_urn: str, optional
        :param profile_urn: member URN for the given LinkedIn profile
        :type profile_urn: str, optional

        :return: Error state. True if error occurred
        :rtype: boolean
        """

        # Validating message length (max size is 300 characters)
        if len(message) > 300:
            self.logger.info("Message too long. Max size is 300 characters")
            return False

        if not profile_urn:
            profile_urn_string = self.get_profile(public_id=profile_public_id)[
                "profile_urn"
            ]
            # Returns string of the form 'urn:li:fs_miniProfile:ACoAACX1hoMBvWqTY21JGe0z91mnmjmLy9Wen4w'
            # We extract the last part of the string
            profile_urn = profile_urn_string.split(":")[-1]

        trackingId = generate_trackingId()
        payload = {
            "trackingId": trackingId,
            "message": message,
            "invitations": [],
            "excludeInvitations": [],
            "invitee": {
                "com.linkedin.voyager.growth.invitation.InviteeProfile": {
                    "profileId": profile_urn
                }
            },
        }
        res = self._post(
            "/growth/normInvitations",
            data=json.dumps(payload),
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
        )

        return res.status_code != 201

    def remove_connection(self, public_profile_id):
        """Remove a given profile as a connection.

        :param public_profile_id: public ID of a LinkedIn profile
        :type public_profile_id: str

        :return: Error state. True if error occurred
        :rtype: boolean
        """
        res = self._post(
            f"/identity/profiles/{public_profile_id}/profileActions?action=disconnect",
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
        )

        return res.status_code != 200

    def track(self, eventBody, eventInfo):
        payload = {"eventBody": eventBody, "eventInfo": eventInfo}
        res = self._post(
            "/li/track",
            base_request=True,
            headers={
                "accept": "*/*",
                "content-type": "text/plain;charset=UTF-8",
            },
            data=json.dumps(payload),
        )

        return res.status_code != 200

    def get_profile_privacy_settings(self, public_profile_id):
        """Fetch privacy settings for a given LinkedIn profile.

        :param public_profile_id: public ID of a LinkedIn profile
        :type public_profile_id: str

        :return: Privacy settings data
        :rtype: dict
        """
        res = self._fetch(
            f"/identity/profiles/{public_profile_id}/privacySettings",
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
        )
        if res.status_code != 200:
            return {}

        data = res.json()
        return data.get("data", {})

    def get_profile_member_badges(self, public_profile_id):
        """Fetch badges for a given LinkedIn profile.

        :param public_profile_id: public ID of a LinkedIn profile
        :type public_profile_id: str

        :return: Badges data
        :rtype: dict
        """
        res = self._fetch(
            f"/identity/profiles/{public_profile_id}/memberBadges",
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
        )
        if res.status_code != 200:
            return {}

        data = res.json()
        return data.get("data", {})

    def get_profile_network_info(self, public_profile_id):
        """Fetch network information for a given LinkedIn profile.

        :param public_profile_id: public ID of a LinkedIn profile
        :type public_profile_id: str

        :return: Network data
        :rtype: dict
        """
        res = self._fetch(
            f"/identity/profiles/{public_profile_id}/networkinfo",
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
        )
        if res.status_code != 200:
            return {}

        data = res.json()
        return data.get("data", {})

    def unfollow_entity(self, urn_id):
        """Unfollow a given entity.

        :param urn_id: URN ID of entity to unfollow
        :type urn_id: str

        :return: Error state. Returns True if error occurred
        :rtype: boolean
        """
        payload = {"urn": f"urn:li:fs_followingInfo:{urn_id}"}
        res = self._post(
            "/feed/follows?action=unfollowByEntityUrn",
            headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
            data=json.dumps(payload),
        )

        err = False
        if res.status_code != 200:
            err = True

        return err

    def _get_list_feed_posts_and_list_feed_urns(
        self, limit=-1, offset=0, exclude_promoted_posts=True
    ):
        """Get a list of URNs from feed sorted by 'Recent' and a list of yet
        unsorted posts, each one of them containing a dict per post.

        :param limit: Maximum length of the returned list, defaults to -1 (no limit)
        :type limit: int, optional
        :param offset: Index to start searching from
        :type offset: int, optional
        :param exclude_promoted_posts: Exclude from the output promoted posts
        :type exclude_promoted_posts: bool, optional

        :return: List of posts and list of URNs
        :rtype: (list, list)
        """
        _PROMOTED_STRING = "Promoted"
        _PROFILE_URL = f"{self.client.LINKEDIN_BASE_URL}/in/"

        l_posts = []
        l_urns = []

        # If count>100 API will return HTTP 400
        count = Linkedin._MAX_UPDATE_COUNT
        if limit == -1:
            limit = Linkedin._MAX_UPDATE_COUNT

        # 'l_urns' equivalent to other functions 'results' variable
        l_urns = []

        while True:
            # when we're close to the limit, only fetch what we need to
            if limit > -1 and limit - len(l_urns) < count:
                count = limit - len(l_urns)
            params = {
                "count": str(count),
                "q": "chronFeed",
                "start": len(l_urns) + offset,
            }
            res = self._fetch(
                f"/feed/updatesV2",
                params=params,
                headers={"accept": "application/vnd.linkedin.normalized+json+2.1"},
            )
            """
            Response includes two keya:
            - ['Data']['*elements']. It includes the posts URNs always
            properly sorted as 'Recent', including yet sponsored posts. The
            downside is that fetching one by one the posts is slower. We will
            save the URNs to later on build a sorted list of posts purging
            promotions
            - ['included']. List with all the posts attributes, but not sorted as
            'Recent' and including promoted posts
            """
            l_raw_posts = res.json().get("included", {})
            l_raw_urns = res.json().get("data", {}).get("*elements", [])

            l_new_posts = parse_list_raw_posts(
                l_raw_posts, self.client.LINKEDIN_BASE_URL
            )
            l_posts.extend(l_new_posts)

            l_urns.extend(parse_list_raw_urns(l_raw_urns))

            # break the loop if we're done searching
            # NOTE: we could also check for the `total` returned in the response.
            # This is in data["data"]["paging"]["total"]
            if (
                (limit > -1 and len(l_urns) >= limit)  # if our results exceed set limit
                or len(l_urns) / count >= Linkedin._MAX_REPEATED_REQUESTS
            ) or len(l_raw_urns) == 0:
                break

            self.logger.debug(f"results grew to {len(l_urns)}")

        return l_posts, l_urns

    def get_feed_posts(self, limit=-1, offset=0, exclude_promoted_posts=True):
        """Get a list of URNs from feed sorted by 'Recent'

        :param limit: Maximum length of the returned list, defaults to -1 (no limit)
        :type limit: int, optional
        :param offset: Index to start searching from
        :type offset: int, optional
        :param exclude_promoted_posts: Exclude from the output promoted posts
        :type exclude_promoted_posts: bool, optional

        :return: List of URNs
        :rtype: list
        """
        l_posts, l_urns = self._get_list_feed_posts_and_list_feed_urns(
            limit, offset, exclude_promoted_posts
        )
        return get_list_posts_sorted_without_promoted(l_urns, l_posts)

    def get_job(self, job_id):
        """Fetch data about a given job.
        :param job_id: LinkedIn job ID
        :type job_id: str

        :return: Job data
        :rtype: dict
        """
        params = {
            "decorationId": "com.linkedin.voyager.deco.jobs.web.shared.WebLightJobPosting-23",
        }

        res = self._fetch(f"/jobs/jobPostings/{job_id}", params=params)

        data = res.json()

        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data["message"]))
            return {}

        return data

    def get_job_skills(self, job_id):
        """Fetch skills associated with a given job.
        :param job_id: LinkedIn job ID
        :type job_id: str

        :return: Job skills
        :rtype: dict
        """
        params = {
            "decorationId": "com.linkedin.voyager.dash.deco.assessments.FullJobSkillMatchInsight-17",
        }
        # https://www.linkedin.com/voyager/api/voyagerAssessmentsDashJobSkillMatchInsight/urn%3Ali%3Afsd_jobSkillMatchInsight%3A3894460323?decorationId=com.linkedin.voyager.dash.deco.assessments.FullJobSkillMatchInsight-17
        res = self._fetch(f"/voyagerAssessmentsDashJobSkillMatchInsight/urn%3Ali%3Afsd_jobSkillMatchInsight%3A{job_id}", params=params)
        data = res.json()

        if data and "status" in data and data["status"] != 200:
            self.logger.info("request failed: {}".format(data.get("message")))
            return {}

        return data

# %%
# from linkedin_api import Linkedin

# Authenticate using any Linkedin account credentials
api = Linkedin('sdudhe92@gmail.com', 'SD@12010220')

# GET a profile
# profile = api.get_profile('billy-g')

# # GET a profiles contact info
# contact_info = api.get_profile_contact_info('billy-g')

# # GET 1st degree connections of a given profile
# connections = api.get_profile_connections('1234asc12304')

# %%
profile = api.get_profile('sudarshandudhe')

# %%
profile
# Out:
# {'summary': "Communication is my passion and my strength. I have honed my skills in strategic communication and media relations through my diverse and impactful experiences in the corporate, non-profit, and academic sectors. Currently, I am pursuing a Master of Science in Corporate and Organizational Communication at Northeastern University, where I am expanding my knowledge and expertise in areas such as crisis management, internal communication, and coaching and mindfulness.\n\nPreviously, I worked as a Communications Executive at CAINCO, collaborating closely with Bolivian reporters and editors to foster productive relationships and enhance the organization's reputation. I developed and implemented comprehensive communication strategies across various sectors, securing significant contracts and organizing successful events and press conferences. I also leveraged my extensive networking skills to gather valuable customer contact information and shape a lead-generation strategy that delivered tangible results. Additionally, I have a Cum Laude degree in Communication and Media Studies from UPB, a certification in body language, and fluency in Italian, Spanish, and English. I am driven to leverage effective communication for impactful results.",
#  'industryName': 'Public Relations & Communications',
#  'lastName': 'Sánchez',
#  'locationName': 'United States',
#  'student': False,
#  'geoCountryName': 'United States',
#  'geoCountryUrn': 'urn:li:fs_geo:103644278',
#  'geoLocationBackfilled': False,
#  'elt': False,
#  'industryUrn': 'urn:li:fs_industry:98',
#  'firstName': 'Luciana',
#  'entityUrn': 'urn:li:fs_profile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#  'geoLocation': {'geoUrn': 'urn:li:fs_geo:102380872'},
#  'geoLocationName': 'Boston, Massachusetts',
#  'location': {'basicLocation': {'countryCode': 'us'}},
#  'headline': 'Communications Strategist | Entrepreneur | Project Management | Internal Communications | Crisis Management | Event Planning | Coaching and Mindfulness | Marketing | Graduate Student in Communications at Northeastern',
#  'displayPictureUrl': 'https://media.licdn.com/dms/image/D4E35AQGDUQ_XBOc0ng/profile-framedphoto-shrink_',
#  'img_400_400': '400_400/0/1711598956737?e=1714179600&v=beta&t=s1ABajqQOqaUqdE64zoZ9CQt2ZNVt6y1SEQ2dLsvnAQ',
#  'img_200_200': '200_200/0/1711598956737?e=1714179600&v=beta&t=FQYdhOtcfacQMd0727ZKSwXvVZbZemQRZ5pcx5lg5To',
#  'img_800_800': '800_800/0/1711598956737?e=1714179600&v=beta&t=3xLk4L__Gv8hVWri8m48eytZhqrqtCtaysCQm1aaUZQ',
#  'img_100_100': '100_100/0/1711598956737?e=1714179600&v=beta&t=OEXTvzy357HaQcMHqiJQqUOCo-GCoJO2aLPzioRstk0',
#  'profile_id': 'ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#  'profile_urn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#  'member_urn': 'urn:li:member:478477491',
#  'public_id': 'lucianasanchezsiles',
#  'experience': [{'locationName': 'Santa Cruz de la Sierra, Santa Cruz, Bolivia',
#    'entityUrn': 'urn:li:fs_position:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,1899870648)',
#    'geoLocationName': 'Santa Cruz de la Sierra, Santa Cruz, Bolivia',
#    'geoUrn': 'urn:li:fs_geo:105318012',
#    'companyName': 'CAINCO',
#    'timePeriod': {'endDate': {'month': 3, 'year': 2023},
#     'startDate': {'month': 1, 'year': 2022}},
#    'description': '-Collaborated closely with Bolivian reporters and editors to foster productive relationships.\n-Worked extensively with journalists on press releases and media outreach.\n-Developed comprehensive corporate communication strategies across various sectors.\n- Provided valuable support in organizing events and press conferences.\n-Expanded and nurtured a wide network of journalist contacts nationwide.\n-Created effective media plans for campaigns, both with and without budget constraints.',
#    'company': {'employeeCountRange': {'start': 51, 'end': 200},
#     'industries': ['Consumer Services']},
#    'title': 'Communications Specialist',
#    'region': 'urn:li:fs_region:(bo,0)',
#    'companyUrn': 'urn:li:fs_miniCompany:1592889',
#    'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQG7kCicKfKc_A/company-logo_'},
#   {'locationName': 'La Paz, Bolivia',
#    'entityUrn': 'urn:li:fs_position:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,2171146827)',
#    'geoLocationName': 'La Paz, Bolivia',
#    'geoUrn': 'urn:li:fs_geo:103809521',
#    'companyName': 'Asociación de Deportes Ecuestres de La Paz (A.D.E.L.P)',
#    'timePeriod': {'endDate': {'month': 12, 'year': 2021},
#     'startDate': {'month': 2, 'year': 2021}},
#    'description': ' -Modernized website and social media management for the association.\n- Successfully secured sponsorships for departmental competitions and facilitated communication with the leadership.\n-Transitioned the association to an online format via https://asociacionecuestrelapaz.com/.\n- Established and managed the association’s Instagram account.\n-Captured departmental contest moments through photography to showcase our achievements.',
#    'title': 'Executive Assistant',
#    'region': 'urn:li:fs_region:(bo,0)'},
#   {'locationName': 'La Paz, Bolivia',
#    'entityUrn': 'urn:li:fs_position:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,1722875781)',
#    'geoLocationName': 'La Paz, Bolivia',
#    'geoUrn': 'urn:li:fs_geo:103809521',
#    'companyName': 'Applicado',
#    'timePeriod': {'endDate': {'month': 5, 'year': 2021},
#     'startDate': {'month': 6, 'year': 2020}},
#    'description': '- Leveraged my extensive networking skills to systematically gather valuable customer contact information, playing a crucial role in shaping a lead generation strategy that delivered tangible results.\n- Spearheaded the development of dynamic communication strategies, harnessing the power of innovative online events to engage audiences effectively and drive impactful outcomes.',
#    'company': {'employeeCountRange': {'start': 2, 'end': 10},
#     'industries': ['Education Management']},
#    'title': 'Corporate Communications Associate',
#    'region': 'urn:li:fs_region:(bo,0)',
#    'companyUrn': 'urn:li:fs_miniCompany:66293411',
#    'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQGG7Kvzx8bjMg/company-logo_'},
#   {'locationName': 'La Paz, Bolivia',
#    'entityUrn': 'urn:li:fs_position:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,1578821312)',
#    'geoLocationName': 'La Paz, Bolivia',
#    'companyName': 'Rodríguez & Baudoin Comunicación Estratégica',
#    'timePeriod': {'endDate': {'month': 3, 'year': 2020},
#     'startDate': {'month': 2, 'year': 2020}},
#    'description': '-Monitored and analyzed communication media channels, encompassing both traditional and modern platforms.\n-Categorized and synthesized news content from diverse media sources.\n-Successfully orchestrated corporate events with precision and finesse.',
#    'company': {'employeeCountRange': {'start': 11, 'end': 50},
#     'industries': ['Public Relations and Communications']},
#    'title': 'Corporate Communications Associate',
#    'companyUrn': 'urn:li:fs_miniCompany:11378447',
#    'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQEMbS_BORTC9A/company-logo_'},
#   {'locationName': 'La Paz, Bolivia',
#    'entityUrn': 'urn:li:fs_position:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,1459158198)',
#    'geoLocationName': 'La Paz, Bolivia',
#    'geoUrn': 'urn:li:fs_geo:103809521',
#    'companyName': 'Banco Interamericano de Desarrollo',
#    'timePeriod': {'endDate': {'month': 6, 'year': 2019},
#     'startDate': {'month': 5, 'year': 2019}},
#    'description': '-Conducted in-depth monitoring and comprehensive documentation of national news and media, with a particular emphasis on tracking developments related to the IDB (Inter-American Development Bank) at the national level.\n-Led the planning and execution of impactful events in partnership with the Ministry of Planning and Development, ensuring meticulous organization and delivering successful outcomes.\n-Orchestrated strategic social media campaigns, strategically crafting and sharing posts to boost engagement, enhance brand visibility, and facilitate effective communication.',
#    'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#     'industries': ['International Trade and Development']},
#    'title': 'Corporate Communications Associate',
#    'region': 'urn:li:fs_region:(bo,0)',
#    'companyUrn': 'urn:li:fs_miniCompany:164401',
#    'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQFSx1RhXSYJuA/company-logo_'}],
#  'education': [{'entityUrn': 'urn:li:fs_education:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,878260287)',
#    'school': {'objectUrn': 'urn:li:school:18506',
#     'entityUrn': 'urn:li:fs_miniSchool:18506',
#     'active': True,
#     'schoolName': 'Northeastern University',
#     'trackingId': 'WJ534bMHTWGkcX1cXNAHJg==',
#     'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQGwTPCvlTQlvw/company-logo_'},
#    'timePeriod': {'endDate': {'month': 4, 'year': 2025},
#     'startDate': {'month': 4, 'year': 2023}},
#    'description': "Pursuing a Master of Science in Corporate and Organizational Communication at Northeastern University empowers me with a versatile skill set poised to thrive in many professional arenas. This program is dedicated to honing expertise in strategic communication methodologies, encompassing negotiation, crisis management, public speaking, and impactful writing. With a curriculum designed to address contemporary communication trends, incorporating experiential learning opportunities and real-world insights from seasoned instructors, I can confidently navigate intricate professional landscapes. This immersive learning experience cultivates the leadership acumen, team management proficiency, and organizational development prowess necessary to drive positive outcomes in today's competitive business environment.",
#    'degreeName': "Master's degree",
#    'schoolName': 'Northeastern University',
#    'fieldOfStudy': 'Science in Corporate and Organizational Communication (Project Management Concentration)',
#    'degreeUrn': 'urn:li:fs_degree:500',
#    'schoolUrn': 'urn:li:fs_miniSchool:18506'},
#   {'entityUrn': 'urn:li:fs_education:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,958190608)',
#    'school': {'objectUrn': 'urn:li:school:188006',
#     'entityUrn': 'urn:li:fs_miniSchool:188006',
#     'active': True,
#     'schoolName': 'ENEB - Escuela de Negocios Europea de Barcelona',
#     'trackingId': '9UzBGc1gRx+AnkLiShhf4A==',
#     'logoUrl': 'https://media.licdn.com/dms/image/C4E0BAQHo72GsHIDlnQ/company-logo_'},
#    'timePeriod': {'endDate': {'month': 4, 'year': 2024},
#     'startDate': {'month': 10, 'year': 2023}},
#    'description': "Pursuing a Master's in Coaching and Mindfulness at ENEB equips me with a diverse skill set to excel in various professional roles. The program focuses on developing skills and competencies in coaching methodologies, mentoring, NLP (Natural Language Processing), emotional intelligence, corporate emotional intelligence, workplace well-being, happiness in organizations, project management, agile methods, and decision-making. This comprehensive curriculum provides me with the tools and knowledge to navigate complex professional challenges and drive positive leadership, team management, and organizational development outcomes.",
#    'degreeName': "Master's degree",
#    'schoolName': 'ENEB - Escuela de Negocios Europea de Barcelona',
#    'fieldOfStudy': 'Master in Coaching and Mindfulness',
#    'degreeUrn': 'urn:li:fs_degree:500',
#    'schoolUrn': 'urn:li:fs_miniSchool:188006'},
#   {'entityUrn': 'urn:li:fs_education:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,559849558)',
#    'school': {'objectUrn': 'urn:li:school:3155509',
#     'entityUrn': 'urn:li:fs_miniSchool:3155509',
#     'active': True,
#     'schoolName': 'Universidad Privada Boliviana',
#     'trackingId': 'cDFBpJlYTVyFKlyC9Hd5Tw==',
#     'logoUrl': 'https://media.licdn.com/dms/image/D4E0BAQFYEhStel0w7Q/company-logo_'},
#    'grade': 'Graduated Cum Laude',
#    'timePeriod': {'endDate': {'month': 9, 'year': 2021},
#     'startDate': {'month': 9, 'year': 2016}},
#    'description': 'My education at Universidad Privada Boliviana (UPB) taught me a comprehensive understanding of communication principles and techniques, including strategic communication, media relations, event management, interpersonal communication, crisis communication, communication theory, journalism, political communication, and public image analysis for politicians and advertising. This diverse skill set has been instrumental in navigating complex communication challenges and driving positive outcomes in my professional endeavors. UPB laid a strong foundation for my career by providing me with the knowledge and skills necessary to excel in various communication roles.',
#    'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100139',
#    'degreeName': 'Communication',
#    'schoolName': 'Universidad Privada Boliviana',
#    'fieldOfStudy': 'Communication and Media Studies',
#    'honors': ['urn:li:fs_honor:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,431424997)',
#     'urn:li:fs_honor:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,570551096)'],
#    'schoolUrn': 'urn:li:fs_miniSchool:3155509'}],
#  'languages': [{'name': 'English', 'proficiency': 'NATIVE_OR_BILINGUAL'},
#   {'name': 'Italian', 'proficiency': 'PROFESSIONAL_WORKING'},
#   {'name': 'Spanish', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#  'publications': [{'date': {'month': 10, 'year': 2023, 'day': 12},
#    'name': 'Empowering Bolivian Businesses Through Communication Audits',
#    'publisher': 'Medium',
#    'url': 'https://medium.com/@lucianasanchez_2969/empowering-bolivian-businesses-through-communication-audit-9a0cab0c3d83',
#    'authors': [{'member': {'firstName': 'Luciana',
#       'lastName': 'Sánchez',
#       'dashEntityUrn': 'urn:li:fsd_profile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'occupation': 'Communications Strategist | Entrepreneur | Project Management | Internal Communications | Crisis Management | Event Planning | Coaching and Mindfulness | Marketing | Graduate Student in Communications at Northeastern',
#       'objectUrn': 'urn:li:member:478477491',
#       'entityUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#           'fileIdentifyingUrlPathSegment': '200_800/0/1710190930107?e=1718841600&v=beta&t=VWH3Jro7eEghJHenggqD4pDhNXUHM8urza6Jx14hWLQ',
#           'expiresAt': 1718841600000,
#           'height': 199},
#          {'width': 1400,
#           'fileIdentifyingUrlPathSegment': '350_1400/0/1710190930107?e=1718841600&v=beta&t=jkKPQAQhS3ql0pEZyPvpAeOuOkm2d2CLY9El6FoXR9E',
#           'expiresAt': 1718841600000,
#           'height': 349}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E16AQE5b8aOyjvadQ/profile-displaybackgroundimage-shrink_'}},
#       'publicIdentifier': 'lucianasanchezsiles',
#       'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#           'fileIdentifyingUrlPathSegment': '400_400/0/1711598956737?e=1714179600&v=beta&t=s1ABajqQOqaUqdE64zoZ9CQt2ZNVt6y1SEQ2dLsvnAQ',
#           'expiresAt': 1714179600000,
#           'height': 400},
#          {'width': 200,
#           'fileIdentifyingUrlPathSegment': '200_200/0/1711598956737?e=1714179600&v=beta&t=FQYdhOtcfacQMd0727ZKSwXvVZbZemQRZ5pcx5lg5To',
#           'expiresAt': 1714179600000,
#           'height': 200},
#          {'width': 800,
#           'fileIdentifyingUrlPathSegment': '800_800/0/1711598956737?e=1714179600&v=beta&t=3xLk4L__Gv8hVWri8m48eytZhqrqtCtaysCQm1aaUZQ',
#           'expiresAt': 1714179600000,
#           'height': 800},
#          {'width': 100,
#           'fileIdentifyingUrlPathSegment': '100_100/0/1711598956737?e=1714179600&v=beta&t=OEXTvzy357HaQcMHqiJQqUOCo-GCoJO2aLPzioRstk0',
#           'expiresAt': 1714179600000,
#           'height': 100}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E35AQGDUQ_XBOc0ng/profile-framedphoto-shrink_'}},
#       'trackingId': '5h7xR5T4RnithNyiEAotHA=='},
#      'profileUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA'}]},
#   {'date': {'month': 6, 'year': 2023, 'day': 15},
#    'name': 'The Majestic Legacy of the Church of San Francisco in La Paz, Bolivia',
#    'publisher': 'Medium',
#    'url': 'https://medium.com/@lucianasanchez_2969/unveiling-the-majestic-legacy-of-the-church-of-san-francisco-in-la-paz-bolivia-a13f8ae25486',
#    'authors': [{'member': {'firstName': 'Luciana',
#       'lastName': 'Sánchez',
#       'dashEntityUrn': 'urn:li:fsd_profile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'occupation': 'Communications Strategist | Entrepreneur | Project Management | Internal Communications | Crisis Management | Event Planning | Coaching and Mindfulness | Marketing | Graduate Student in Communications at Northeastern',
#       'objectUrn': 'urn:li:member:478477491',
#       'entityUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#           'fileIdentifyingUrlPathSegment': '200_800/0/1710190930107?e=1718841600&v=beta&t=VWH3Jro7eEghJHenggqD4pDhNXUHM8urza6Jx14hWLQ',
#           'expiresAt': 1718841600000,
#           'height': 199},
#          {'width': 1400,
#           'fileIdentifyingUrlPathSegment': '350_1400/0/1710190930107?e=1718841600&v=beta&t=jkKPQAQhS3ql0pEZyPvpAeOuOkm2d2CLY9El6FoXR9E',
#           'expiresAt': 1718841600000,
#           'height': 349}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E16AQE5b8aOyjvadQ/profile-displaybackgroundimage-shrink_'}},
#       'publicIdentifier': 'lucianasanchezsiles',
#       'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#           'fileIdentifyingUrlPathSegment': '400_400/0/1711598956737?e=1714179600&v=beta&t=s1ABajqQOqaUqdE64zoZ9CQt2ZNVt6y1SEQ2dLsvnAQ',
#           'expiresAt': 1714179600000,
#           'height': 400},
#          {'width': 200,
#           'fileIdentifyingUrlPathSegment': '200_200/0/1711598956737?e=1714179600&v=beta&t=FQYdhOtcfacQMd0727ZKSwXvVZbZemQRZ5pcx5lg5To',
#           'expiresAt': 1714179600000,
#           'height': 200},
#          {'width': 800,
#           'fileIdentifyingUrlPathSegment': '800_800/0/1711598956737?e=1714179600&v=beta&t=3xLk4L__Gv8hVWri8m48eytZhqrqtCtaysCQm1aaUZQ',
#           'expiresAt': 1714179600000,
#           'height': 800},
#          {'width': 100,
#           'fileIdentifyingUrlPathSegment': '100_100/0/1711598956737?e=1714179600&v=beta&t=OEXTvzy357HaQcMHqiJQqUOCo-GCoJO2aLPzioRstk0',
#           'expiresAt': 1714179600000,
#           'height': 100}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E35AQGDUQ_XBOc0ng/profile-framedphoto-shrink_'}},
#       'trackingId': '5h7xR5T4RnithNyiEAotHA=='},
#      'profileUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA'}]},
#   {'date': {'month': 10, 'year': 2019, 'day': 8},
#    'name': 'Chiquitanía El cementerio más grande del mundo',
#    'publisher': 'Multimedia UPB',
#    'url': 'http://comunicate.upb.edu/?p=801&fbclid=IwAR0uIwIqN616etveFl-x5nkS75y9Tb8RZToGVb9wcA4RBH-tF2nyAdcxmZ4',
#    'authors': [{'member': {'firstName': 'Luciana',
#       'lastName': 'Sánchez',
#       'dashEntityUrn': 'urn:li:fsd_profile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'occupation': 'Communications Strategist | Entrepreneur | Project Management | Internal Communications | Crisis Management | Event Planning | Coaching and Mindfulness | Marketing | Graduate Student in Communications at Northeastern',
#       'objectUrn': 'urn:li:member:478477491',
#       'entityUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#           'fileIdentifyingUrlPathSegment': '200_800/0/1710190930107?e=1718841600&v=beta&t=VWH3Jro7eEghJHenggqD4pDhNXUHM8urza6Jx14hWLQ',
#           'expiresAt': 1718841600000,
#           'height': 199},
#          {'width': 1400,
#           'fileIdentifyingUrlPathSegment': '350_1400/0/1710190930107?e=1718841600&v=beta&t=jkKPQAQhS3ql0pEZyPvpAeOuOkm2d2CLY9El6FoXR9E',
#           'expiresAt': 1718841600000,
#           'height': 349}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E16AQE5b8aOyjvadQ/profile-displaybackgroundimage-shrink_'}},
#       'publicIdentifier': 'lucianasanchezsiles',
#       'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#           'fileIdentifyingUrlPathSegment': '400_400/0/1711598956737?e=1714179600&v=beta&t=s1ABajqQOqaUqdE64zoZ9CQt2ZNVt6y1SEQ2dLsvnAQ',
#           'expiresAt': 1714179600000,
#           'height': 400},
#          {'width': 200,
#           'fileIdentifyingUrlPathSegment': '200_200/0/1711598956737?e=1714179600&v=beta&t=FQYdhOtcfacQMd0727ZKSwXvVZbZemQRZ5pcx5lg5To',
#           'expiresAt': 1714179600000,
#           'height': 200},
#          {'width': 800,
#           'fileIdentifyingUrlPathSegment': '800_800/0/1711598956737?e=1714179600&v=beta&t=3xLk4L__Gv8hVWri8m48eytZhqrqtCtaysCQm1aaUZQ',
#           'expiresAt': 1714179600000,
#           'height': 800},
#          {'width': 100,
#           'fileIdentifyingUrlPathSegment': '100_100/0/1711598956737?e=1714179600&v=beta&t=OEXTvzy357HaQcMHqiJQqUOCo-GCoJO2aLPzioRstk0',
#           'expiresAt': 1714179600000,
#           'height': 100}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E35AQGDUQ_XBOc0ng/profile-framedphoto-shrink_'}},
#       'trackingId': '5h7xR5T4RnithNyiEAotHA=='},
#      'profileUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA'},
#     {'name': 'Kiara Ando'},
#     {'name': 'Canela Porcel'}]},
#   {'date': {'month': 2, 'year': 2019, 'day': 20},
#    'name': '"Estudiantes destacados son premiados"',
#    'publisher': 'Comunícate UPB',
#    'url': 'http://comunicate.upb.edu/?p=667',
#    'authors': [{'member': {'firstName': 'Luciana',
#       'lastName': 'Sánchez',
#       'dashEntityUrn': 'urn:li:fsd_profile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'occupation': 'Communications Strategist | Entrepreneur | Project Management | Internal Communications | Crisis Management | Event Planning | Coaching and Mindfulness | Marketing | Graduate Student in Communications at Northeastern',
#       'objectUrn': 'urn:li:member:478477491',
#       'entityUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA',
#       'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#           'fileIdentifyingUrlPathSegment': '200_800/0/1710190930107?e=1718841600&v=beta&t=VWH3Jro7eEghJHenggqD4pDhNXUHM8urza6Jx14hWLQ',
#           'expiresAt': 1718841600000,
#           'height': 199},
#          {'width': 1400,
#           'fileIdentifyingUrlPathSegment': '350_1400/0/1710190930107?e=1718841600&v=beta&t=jkKPQAQhS3ql0pEZyPvpAeOuOkm2d2CLY9El6FoXR9E',
#           'expiresAt': 1718841600000,
#           'height': 349}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E16AQE5b8aOyjvadQ/profile-displaybackgroundimage-shrink_'}},
#       'publicIdentifier': 'lucianasanchezsiles',
#       'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#           'fileIdentifyingUrlPathSegment': '400_400/0/1711598956737?e=1714179600&v=beta&t=s1ABajqQOqaUqdE64zoZ9CQt2ZNVt6y1SEQ2dLsvnAQ',
#           'expiresAt': 1714179600000,
#           'height': 400},
#          {'width': 200,
#           'fileIdentifyingUrlPathSegment': '200_200/0/1711598956737?e=1714179600&v=beta&t=FQYdhOtcfacQMd0727ZKSwXvVZbZemQRZ5pcx5lg5To',
#           'expiresAt': 1714179600000,
#           'height': 200},
#          {'width': 800,
#           'fileIdentifyingUrlPathSegment': '800_800/0/1711598956737?e=1714179600&v=beta&t=3xLk4L__Gv8hVWri8m48eytZhqrqtCtaysCQm1aaUZQ',
#           'expiresAt': 1714179600000,
#           'height': 800},
#          {'width': 100,
#           'fileIdentifyingUrlPathSegment': '100_100/0/1711598956737?e=1714179600&v=beta&t=OEXTvzy357HaQcMHqiJQqUOCo-GCoJO2aLPzioRstk0',
#           'expiresAt': 1714179600000,
#           'height': 100}],
#         'rootUrl': 'https://media.licdn.com/dms/image/D4E35AQGDUQ_XBOc0ng/profile-framedphoto-shrink_'}},
#       'trackingId': '5h7xR5T4RnithNyiEAotHA=='},
#      'profileUrn': 'urn:li:fs_miniProfile:ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA'}]}],
#  'certifications': [{'authority': 'LinkedIn',
#    'name': 'Body Language for Women',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 'Ajk4JzeHQJC17DxGoeYtHw=='},
#    'displaySource': 'linkedin.com',
#    'companyUrn': 'urn:li:fs_miniCompany:1337',
#    'url': 'https://www.linkedin.com/learning/certificates/a449d2e6c0ee084b827add5bc12db824c9132bedaec2c5cdb04bf560d8bd0276?trk=backfilled_certificate'},
#   {'authority': 'Universidad Privada Boliviana',
#    'name': 'Participation Certificate "Emprende"',
#    'timePeriod': {'startDate': {'month': 6, 'year': 2018}},
#    'company': {'objectUrn': 'urn:li:company:24978708',
#     'entityUrn': 'urn:li:fs_miniCompany:24978708',
#     'name': 'Universidad Privada Boliviana',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1711077797395?e=1721865600&v=beta&t=zG1094tVt3fhLyF9Y7ik6_924Dh2HMocPKlwbnwF8sA',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1711077797395?e=1721865600&v=beta&t=iVyiAV_3o_I7gdbGjNQZwcnj7zZo5o4HZhefQVm-9VI',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1711077797395?e=1721865600&v=beta&t=bRCKE3tuBQwG2njtFpvvi-1Xpj2lfIK8UggIFjR6W2A',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/D4E0BAQFYEhStel0w7Q/company-logo_'}},
#     'universalName': 'upboficial',
#     'dashCompanyUrn': 'urn:li:fsd_company:24978708',
#     'trackingId': 'EZJZOMIFSdKSH7CO+qRzHw=='},
#    'companyUrn': 'urn:li:fs_miniCompany:24978708'},
#   {'authority': 'Maltalingua School of English',
#    'name': 'IELTS Certification Course (C1)',
#    'timePeriod': {'startDate': {'month': 1, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:2691216',
#     'entityUrn': 'urn:li:fs_miniCompany:2691216',
#     'name': 'Maltalingua School of English',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1631364498103?e=1721865600&v=beta&t=lgjVTi3qOXrF0pOXtzrpklBCvHfHpApdbrFehhrouZY',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1631364498103?e=1721865600&v=beta&t=awazW2-yFClZtTcOASevT9UP9jdofDs_B3VjR3zkLRg',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1631364498103?e=1721865600&v=beta&t=F2srcUmzBcELy1Vjro1HX9cKZOMUp9ETtboBOhZre7g',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHb5X4x2WkSHg/company-logo_'}},
#     'universalName': 'maltalingua',
#     'dashCompanyUrn': 'urn:li:fsd_company:2691216',
#     'trackingId': '53r9Wz/EQy+stjfMikf3/A=='},
#    'companyUrn': 'urn:li:fs_miniCompany:2691216'},
#   {'authority': 'Maltalingua School of English',
#    'name': 'Advanced English Course C1',
#    'timePeriod': {'startDate': {'month': 1, 'year': 2017}},
#    'company': {'objectUrn': 'urn:li:company:2691216',
#     'entityUrn': 'urn:li:fs_miniCompany:2691216',
#     'name': 'Maltalingua School of English',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1631364498103?e=1721865600&v=beta&t=lgjVTi3qOXrF0pOXtzrpklBCvHfHpApdbrFehhrouZY',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1631364498103?e=1721865600&v=beta&t=awazW2-yFClZtTcOASevT9UP9jdofDs_B3VjR3zkLRg',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1631364498103?e=1721865600&v=beta&t=F2srcUmzBcELy1Vjro1HX9cKZOMUp9ETtboBOhZre7g',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHb5X4x2WkSHg/company-logo_'}},
#     'universalName': 'maltalingua',
#     'dashCompanyUrn': 'urn:li:fsd_company:2691216',
#     'trackingId': '7wV+iKinSuaFGrEFl6r5yQ=='},
#    'companyUrn': 'urn:li:fs_miniCompany:2691216'},
#   {'authority': 'LinkedIn',
#    'name': 'Event Planning Foundations',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 'AF72K87yQH2rtVIt3x2SuQ=='},
#    'displaySource': 'linkedin.com',
#    'companyUrn': 'urn:li:fs_miniCompany:1337',
#    'url': 'https://www.linkedin.com/learning/certificates/b31141096e02822dcdcec2faed5fa94f18e07e2310b4203ced99b9274ffc4c3c?trk=backfilled_certificate'},
#   {'authority': 'LinkedIn',
#    'name': 'Connecting with Peers in the Workplace',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'licenseNumber': 'AWD5q4B0_a4bnsY9EUCaft6SYlBX',
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 's6EEJAU5SAiPIclvFTUGHA=='},
#    'companyUrn': 'urn:li:fs_miniCompany:1337'},
#   {'authority': 'LinkedIn',
#    'name': 'Delivering Bad News to a Customer',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 'xxb0yXGHRVWUvnQIQoEFBg=='},
#    'displaySource': 'linkedin.com',
#    'companyUrn': 'urn:li:fs_miniCompany:1337',
#    'url': 'https://www.linkedin.com/learning/certificates/73cd791609ed0a995a89f763e60cdb84f65fbd16039503daba63100417ce589b?trk=backfilled_certificate'},
#   {'authority': 'LinkedIn',
#    'name': 'Learning from Failure',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 'btlmLfmvQ4i8OvJMyHaXPg=='},
#    'displaySource': 'linkedin.com',
#    'companyUrn': 'urn:li:fs_miniCompany:1337',
#    'url': 'https://www.linkedin.com/learning/certificates/d70d39cca16a7112648f5e533b675a44d918b60e7135724bd4e39bb03b3d29b4?trk=backfilled_certificate'},
#   {'authority': 'LinkedIn',
#    'name': 'Customer Service: Handling Abusive Customers',
#    'timePeriod': {'startDate': {'month': 4, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:1337',
#     'entityUrn': 'urn:li:fs_miniCompany:1337',
#     'name': 'LinkedIn',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=RBpq_-2EFgFpzeBR_9JzX9a6UIC_9Y9vujJxAR059-Y',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=uJfd-zV0N17fvc-dapl7ie1fZr_1L2QHDBIcbFCPVBc',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1638831590218/linkedin_logo?e=1721865600&v=beta&t=gLLwbLahSxAe34vFcBtF-tTopfim_Y_zbbAUfPXy0VQ',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C560BAQHaVYd13rRz3A/company-logo_'}},
#     'universalName': 'linkedin',
#     'dashCompanyUrn': 'urn:li:fsd_company:1337',
#     'trackingId': 'NaIhIJb0QAaUid3HUA4+Yg=='},
#    'displaySource': 'linkedin.com',
#    'companyUrn': 'urn:li:fs_miniCompany:1337',
#    'url': 'https://www.linkedin.com/learning/certificates/17fa61b0db44d9471983a37927b68ce41e5ba24feb60364002656786cd5fea1a?trk=backfilled_certificate'},
#   {'authority': 'Inter-American Development Bank',
#    'name': 'Manejo de su presencia en redes sociales',
#    'timePeriod': {'endDate': {'month': 6, 'year': 2019},
#     'startDate': {'month': 5, 'year': 2019}},
#    'company': {'objectUrn': 'urn:li:company:164401',
#     'entityUrn': 'urn:li:fs_miniCompany:164401',
#     'name': 'Inter-American Development Bank',
#     'showcase': False,
#     'active': True,
#     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1677187298858/inter_american_development_bank_logo?e=1721865600&v=beta&t=l5swGRM7VjTHi4Aic3BgNcVV2o9g2Oo08RxwM2USWCA',
#         'expiresAt': 1721865600000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1677187298858/inter_american_development_bank_logo?e=1721865600&v=beta&t=nWpVDboNkMSwmlykaawDLeMq2ayQFNXTKyNvT6Jq1fU',
#         'expiresAt': 1721865600000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1677187298858/inter_american_development_bank_logo?e=1721865600&v=beta&t=Z-jgNjTYH0hwMNLMGwsSZc9MM7Yy2DEbp6QKcAePYU4',
#         'expiresAt': 1721865600000,
#         'height': 400}],
#       'rootUrl': 'https://media.licdn.com/dms/image/C4E0BAQFSx1RhXSYJuA/company-logo_'}},
#     'universalName': 'inter-american-development-bank',
#     'dashCompanyUrn': 'urn:li:fsd_company:164401',
#     'trackingId': 'S7ycaS7UQReyYhS4HcrR9A=='},
#    'companyUrn': 'urn:li:fs_miniCompany:164401'}],
#  'volunteer': [],
#  'honors': [{'description': 'GPA 88.51/100\n\n(Honorable Mentions for Good Academic Performance)\n\nThe UPB awards honorable mentions to students who have distinguished themselves\nin their academic performance during their professional career, according to the following\nclassification of the final grade average of the subjects taken at UPB:\n\n- CUM LAUDE From 87.50 to 89.99 points',
#    'occupation': 'urn:li:fs_education:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,559849558)',
#    'title': 'Graduated Cum Laude',
#    'issueDate': {'month': 11, 'year': 2021},
#    'issuer': 'Universidad Privada Boliviana'},
#   {'description': 'I am deeply honored to receive the "Golden Emblem of the Canine Training Center." This recognition symbolizes my unwavering dedication and selfless commitment to serving society, the institution, and our nation. It is genuinely humbling to be acknowledged for my contributions to the Bolivian Police institution, especially within the Canine Training Center. This award motivates me to continue striving for excellence and to inspire others to support our institution\'s mission. I am grateful for this recognition and look forward to the award ceremony on November 11th, 2021.',
#    'title': '“Emblema de Oro del Centro de Adiestramiento de Canes” - Golden Emblem of the Canine Training Center.',
#    'issueDate': {'month': 11, 'year': 2021},
#    'issuer': 'Policía Boliviana- Centro de Adiestramiento de Canes (Bolivian Police - Canine Training Center)'},
#   {'description': 'In the first half of 2018, I ranked among the top five students in my degree program, an honor reserved for those with an average grade exceeding 87.5 out of 100. Notably, my semester grade during that period was 95.91/100.',
#    'occupation': 'urn:li:fs_education:(ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA,559849558)',
#    'title': 'Honor Roll (1st Semester 2018)',
#    'issueDate': {'month': 8, 'year': 2018}}],
#  'projects': [],
#  'skills': [{'name': 'Surveys'},
#   {'name': 'Key Performance Indicators'},
#   {'name': 'Benchmarking'},
#   {'name': 'Stakeholder Analysis'}],
#  'urn_id': 'ACoAAByE_LMBQulWScP4DHFnlCxYMDzAzPDtWjA'}

# %%
# contact_info = api.get_profile_contact_info('billy-g')
# contact_info
# Out:
# {'email_address': None,
#  'websites': [{'url': 'www.billygraban.com', 'label': 'PERSONAL'}],
#  'twitter': [],
#  'birthdate': {'month': 6, 'day': 4},
#  'ims': None,
#  'phone_numbers': []}

# %%
connections = api.get_profile_connections('1234asc12304')
# 'ACoAABmW8OcBkHVy3a_d6KXoLULumL_yKix-YOw'

# %%
# connections

# %%
jobs = api.search_jobs(keywords="Software Developer")
# , location_name="Boston, Massachusetts, United States")
# , job_type=['full-time']

# %%
jobs
# Out:
# [{'trackingUrn': 'urn:li:jobPosting:3901990442',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901990442'},
#  {'trackingUrn': 'urn:li:jobPosting:3901965362',
#   'repostedJob': False,
#   'title': 'Software Engineer w/ GenAI',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '178581593',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901965362'},
#  {'trackingUrn': 'urn:li:jobPosting:3906214011',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '225002295',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906214011'},
#  {'trackingUrn': 'urn:li:jobPosting:3903831136',
#   'repostedJob': False,
#   'title': '2024 Intern - Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '304512131',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903831136'},
#  {'trackingUrn': 'urn:li:jobPosting:3903878684',
#   'repostedJob': True,
#   'title': 'Python- Data Analytics -Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12880609',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903878684'},
#  {'trackingUrn': 'urn:li:jobPosting:3902389621',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '85254542',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902389621'},
#  {'trackingUrn': 'urn:li:jobPosting:3904536390',
#   'repostedJob': False,
#   'title': 'Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '7580408',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904536390'},
#  {'trackingUrn': 'urn:li:jobPosting:3902366180',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902366180'},
#  {'trackingUrn': 'urn:li:jobPosting:3902366181',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902366181'},
#  {'trackingUrn': 'urn:li:jobPosting:3901957260',
#   'repostedJob': False,
#   'title': 'Back End Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '174993089',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901957260'},
#  {'trackingUrn': 'urn:li:jobPosting:3903879731',
#   'repostedJob': True,
#   'title': 'Data Engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '323270563',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903879731'},
#  {'trackingUrn': 'urn:li:jobPosting:3904514054',
#   'repostedJob': False,
#   'title': 'Python Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560702149',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904514054'},
#  {'trackingUrn': 'urn:li:jobPosting:3904706616',
#   'repostedJob': False,
#   'title': 'Software Development Intern - Summer 2024',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12929960',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904706616'},
#  {'trackingUrn': 'urn:li:jobPosting:3905894515',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '590108837',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905894515'},
#  {'trackingUrn': 'urn:li:jobPosting:3905693803',
#   'repostedJob': True,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6620189',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905693803'},
#  {'trackingUrn': 'urn:li:jobPosting:3903838894',
#   'repostedJob': False,
#   'title': 'Software Engineer Intern',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '520771915',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903838894'},
#  {'trackingUrn': 'urn:li:jobPosting:3905304072',
#   'repostedJob': False,
#   'title': 'Software Engineer I',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '23528601',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905304072'},
#  {'trackingUrn': 'urn:li:jobPosting:3905360656',
#   'repostedJob': True,
#   'title': 'Software Developer Intern - Backend',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9281255',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905360656'},
#  {'trackingUrn': 'urn:li:jobPosting:3901966206',
#   'repostedJob': False,
#   'title': 'Software Engineer III (Python)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901966206'},
#  {'trackingUrn': 'urn:li:jobPosting:3905312247',
#   'repostedJob': False,
#   'title': 'Software Development Engineer I',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '479340824',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905312247'},
#  {'trackingUrn': 'urn:li:jobPosting:3893491037',
#   'repostedJob': True,
#   'title': 'Junior Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1102818096',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3893491037'},
#  {'trackingUrn': 'urn:li:jobPosting:3902838562',
#   'repostedJob': False,
#   'title': 'Java developer (spark)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '277181585',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902838562'},
#  {'trackingUrn': 'urn:li:jobPosting:3905339036',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '348868397',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905339036'},
#  {'trackingUrn': 'urn:li:jobPosting:3905311281',
#   'repostedJob': False,
#   'title': 'Software Development Engineer I',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '479340824',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905311281'},
#  {'trackingUrn': 'urn:li:jobPosting:3906220663',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '679384919',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906220663'},
#  {'trackingUrn': 'urn:li:jobPosting:3901949271',
#   'repostedJob': False,
#   'title': 'Software Engineering Intern',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '193282778',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901949271'},
#  {'trackingUrn': 'urn:li:jobPosting:3904593119',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '756398502',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904593119'},
#  {'trackingUrn': 'urn:li:jobPosting:3902325012',
#   'repostedJob': False,
#   'title': 'Data Scientist/ Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '129663413',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902325012'},
#  {'trackingUrn': 'urn:li:jobPosting:3903844065',
#   'repostedJob': False,
#   'title': 'Software Engineer (Hybrid)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '777789',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903844065'},
#  {'trackingUrn': 'urn:li:jobPosting:3902840602',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '21492352',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902840602'},
#  {'trackingUrn': 'urn:li:jobPosting:3903852011',
#   'repostedJob': True,
#   'title': 'Software Development Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '7745488',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903852011'},
#  {'trackingUrn': 'urn:li:jobPosting:3905331980',
#   'repostedJob': False,
#   'title': 'Software Developer I - Backend',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '82178899',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905331980'},
#  {'trackingUrn': 'urn:li:jobPosting:3840253272',
#   'repostedJob': True,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '515683360',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3840253272'},
#  {'trackingUrn': 'urn:li:jobPosting:3905315166',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '583838508',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905315166'},
#  {'trackingUrn': 'urn:li:jobPosting:3904518251',
#   'repostedJob': False,
#   'title': 'Data Engineer - 2222820',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '4437624',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904518251'},
#  {'trackingUrn': 'urn:li:jobPosting:3902846318',
#   'repostedJob': False,
#   'title': 'Python Software Engineer (Onsite in Houston)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '147486046',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902846318'},
#  {'trackingUrn': 'urn:li:jobPosting:3899928886',
#   'repostedJob': True,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '142738431',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3899928886'},
#  {'trackingUrn': 'urn:li:jobPosting:3905883114',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905883114'},
#  {'trackingUrn': 'urn:li:jobPosting:3880404671',
#   'repostedJob': True,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '490815526',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3880404671'},
#  {'trackingUrn': 'urn:li:jobPosting:3902834229',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1248235182',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902834229'},
#  {'trackingUrn': 'urn:li:jobPosting:3906226023',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '894643671',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906226023'},
#  {'trackingUrn': 'urn:li:jobPosting:3901952554',
#   'repostedJob': False,
#   'title': 'Data Engineer-SQL/ Python/ Data Analysis',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '149275349',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901952554'},
#  {'trackingUrn': 'urn:li:jobPosting:3905333449',
#   'repostedJob': False,
#   'title': 'Software Engineer - New Grad',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '80849838',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905333449'},
#  {'trackingUrn': 'urn:li:jobPosting:3906225846',
#   'repostedJob': False,
#   'title': 'Lead Software Engineer (001548)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9634197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906225846'},
#  {'trackingUrn': 'urn:li:jobPosting:3886064845',
#   'repostedJob': True,
#   'title': 'Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '281411987',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3886064845'},
#  {'trackingUrn': 'urn:li:jobPosting:3902377151',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '5803041',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902377151'},
#  {'trackingUrn': 'urn:li:jobPosting:3903877729',
#   'repostedJob': True,
#   'title': '2024 Intern - Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '484366381',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903877729'},
#  {'trackingUrn': 'urn:li:jobPosting:3902831417',
#   'repostedJob': False,
#   'title': 'Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1145041641',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902831417'},
#  {'trackingUrn': 'urn:li:jobPosting:3903877728',
#   'repostedJob': True,
#   'title': 'Software Development Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '484366381',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903877728'},
#  {'trackingUrn': 'urn:li:jobPosting:3887824462',
#   'repostedJob': True,
#   'title': 'Mobile Application Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '476089213',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3887824462'},
#  {'trackingUrn': 'urn:li:jobPosting:3902393442',
#   'repostedJob': False,
#   'title': 'Quantitative Programmer (Java)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '930255264',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902393442'},
#  {'trackingUrn': 'urn:li:jobPosting:3905397635',
#   'repostedJob': False,
#   'title': 'Software Engineer – UCS',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '98226753',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905397635'},
#  {'trackingUrn': 'urn:li:jobPosting:3902829887',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1015222792',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902829887'},
#  {'trackingUrn': 'urn:li:jobPosting:3902839580',
#   'repostedJob': True,
#   'title': 'Machine Learning Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '214625077',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902839580'},
#  {'trackingUrn': 'urn:li:jobPosting:3903838223',
#   'repostedJob': False,
#   'title': 'Software Engineer 2',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '205177503',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903838223'},
#  {'trackingUrn': 'urn:li:jobPosting:3906231013',
#   'repostedJob': False,
#   'title': 'Senior iOS Software Engineer - Growth',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '421266878',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906231013'},
#  {'trackingUrn': 'urn:li:jobPosting:3904595950',
#   'repostedJob': False,
#   'title': 'Machine Learning Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560383623',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904595950'},
#  {'trackingUrn': 'urn:li:jobPosting:3906224397',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer II, Reporting',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '85836753',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906224397'},
#  {'trackingUrn': 'urn:li:jobPosting:3905881155',
#   'repostedJob': False,
#   'title': 'Python Data Engineer ( Hybrid in LA or Irvine)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905881155'},
#  {'trackingUrn': 'urn:li:jobPosting:3902384958',
#   'repostedJob': False,
#   'title': 'Software Engineer III',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902384958'},
#  {'trackingUrn': 'urn:li:jobPosting:3813774543',
#   'repostedJob': True,
#   'title': 'Machine Learning Engineer – Data Science',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '68809300',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3813774543'},
#  {'trackingUrn': 'urn:li:jobPosting:3906222768',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer II, Reporting',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '85836753',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906222768'},
#  {'trackingUrn': 'urn:li:jobPosting:3903827343',
#   'repostedJob': False,
#   'title': 'Intern - Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '676160048',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903827343'},
#  {'trackingUrn': 'urn:li:jobPosting:3905885128',
#   'repostedJob': False,
#   'title': 'Quantitative Programmer (Java)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905885128'},
#  {'trackingUrn': 'urn:li:jobPosting:3904507517',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '847125334',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904507517'},
#  {'trackingUrn': 'urn:li:jobPosting:3904514051',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560702149',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904514051'},
#  {'trackingUrn': 'urn:li:jobPosting:3905892001',
#   'repostedJob': False,
#   'title': 'Software Development Intern - New York',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '322111197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905892001'},
#  {'trackingUrn': 'urn:li:jobPosting:3905883094',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905883094'},
#  {'trackingUrn': 'urn:li:jobPosting:3902333082',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '391956572',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902333082'},
#  {'trackingUrn': 'urn:li:jobPosting:3905382527',
#   'repostedJob': True,
#   'title': 'Software Engineer, AI',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '84891654',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905382527'},
#  {'trackingUrn': 'urn:li:jobPosting:3903878661',
#   'repostedJob': True,
#   'title': 'Python- Data Analytics -Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12880609',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903878661'},
#  {'trackingUrn': 'urn:li:jobPosting:3904069987',
#   'repostedJob': False,
#   'title': 'Software Development Intern',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '2872952',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904069987'},
#  {'trackingUrn': 'urn:li:jobPosting:3903843077',
#   'repostedJob': False,
#   'title': 'Software Engineer (Hybrid)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '777789',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903843077'},
#  {'trackingUrn': 'urn:li:jobPosting:3900936314',
#   'repostedJob': True,
#   'title': 'Software Engineer-Spark',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '273332522',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3900936314'},
#  {'trackingUrn': 'urn:li:jobPosting:3905331884',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '348868397',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905331884'},
#  {'trackingUrn': 'urn:li:jobPosting:3906225789',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer (001479)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9634197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906225789'},
#  {'trackingUrn': 'urn:li:jobPosting:3903827371',
#   'repostedJob': False,
#   'title': '2024 Intern - Finance Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '304512131',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903827371'},
#  {'trackingUrn': 'urn:li:jobPosting:3902393383',
#   'repostedJob': False,
#   'title': 'Data Engineer / Scientist - for New University Grads (Small, Fun Team 🤓)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12396795',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902393383'},
#  {'trackingUrn': 'urn:li:jobPosting:3904599802',
#   'repostedJob': False,
#   'title': 'Software Engineer I',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '596036194',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904599802'},
#  {'trackingUrn': 'urn:li:jobPosting:3904702598',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '110219241',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904702598'},
#  {'trackingUrn': 'urn:li:jobPosting:3903051090',
#   'repostedJob': True,
#   'title': 'Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '677183241',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903051090'},
#  {'trackingUrn': 'urn:li:jobPosting:3906224794',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer (#001483)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9634197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906224794'},
#  {'trackingUrn': 'urn:li:jobPosting:3902300154',
#   'repostedJob': False,
#   'title': 'Full Stack Java Python Spark SQL Software Engineer III',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '785091003',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902300154'},
#  {'trackingUrn': 'urn:li:jobPosting:3901952530',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '17705204',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901952530'},
#  {'trackingUrn': 'urn:li:jobPosting:3903876865',
#   'repostedJob': True,
#   'title': 'Python- Data Analytics -Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12880609',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903876865'},
#  {'trackingUrn': 'urn:li:jobPosting:3905825515',
#   'repostedJob': False,
#   'title': 'Back End Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '459521996',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905825515'},
#  {'trackingUrn': 'urn:li:jobPosting:3902363686',
#   'repostedJob': False,
#   'title': 'Software Engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902363686'},
#  {'trackingUrn': 'urn:li:jobPosting:3906227249',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer II, Reporting',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '85836753',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906227249'},
#  {'trackingUrn': 'urn:li:jobPosting:3901963311',
#   'repostedJob': False,
#   'title': '55ip - Software Engineer III - Python',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901963311'},
#  {'trackingUrn': 'urn:li:jobPosting:3901950918',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901950918'},
#  {'trackingUrn': 'urn:li:jobPosting:3902363650',
#   'repostedJob': False,
#   'title': 'Software Engineer ll',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902363650'},
#  {'trackingUrn': 'urn:li:jobPosting:3904523626',
#   'repostedJob': False,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '824242219',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904523626'},
#  {'trackingUrn': 'urn:li:jobPosting:3904534291',
#   'repostedJob': True,
#   'title': 'Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '60946462',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904534291'},
#  {'trackingUrn': 'urn:li:jobPosting:3902367100',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902367100'},
#  {'trackingUrn': 'urn:li:jobPosting:3904091360',
#   'repostedJob': False,
#   'title': 'Machine Learning Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '440143621',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904091360'},
#  {'trackingUrn': 'urn:li:jobPosting:3902366015',
#   'repostedJob': False,
#   'title': '\u200b\u200bSoftware Engineer II \u200b',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902366015'},
#  {'trackingUrn': 'urn:li:jobPosting:3901060575',
#   'repostedJob': True,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '665721300',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901060575'},
#  {'trackingUrn': 'urn:li:jobPosting:3885522011',
#   'repostedJob': True,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '4634913',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3885522011'},
#  {'trackingUrn': 'urn:li:jobPosting:3901965244',
#   'repostedJob': False,
#   'title': 'Java Software Engineer III',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901965244'},
#  {'trackingUrn': 'urn:li:jobPosting:3903879663',
#   'repostedJob': True,
#   'title': 'Python- Data Analytics -Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '12880609',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903879663'},
#  {'trackingUrn': 'urn:li:jobPosting:3901966208',
#   'repostedJob': False,
#   'title': 'Software Engineer III Full Stack - Java and ReactJS',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901966208'},
#  {'trackingUrn': 'urn:li:jobPosting:3905298557',
#   'repostedJob': False,
#   'title': 'Jr. Software Developers',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '16355722',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905298557'},
#  {'trackingUrn': 'urn:li:jobPosting:3902349833',
#   'repostedJob': False,
#   'title': 'Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '14785653',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902349833'},
#  {'trackingUrn': 'urn:li:jobPosting:3902385943',
#   'repostedJob': False,
#   'title': 'Software Engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6077559',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902385943'},
#  {'trackingUrn': 'urn:li:jobPosting:3904069446',
#   'repostedJob': False,
#   'title': 'Backend Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '70016727',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904069446'},
#  {'trackingUrn': 'urn:li:jobPosting:3906224968',
#   'repostedJob': False,
#   'title': 'Lead Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9634197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906224968'},
#  {'trackingUrn': 'urn:li:jobPosting:3903844588',
#   'repostedJob': False,
#   'title': 'Principal Software Engineer - Backend - Python (Xpanse)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '20548504',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903844588'},
#  {'trackingUrn': 'urn:li:jobPosting:3903836162',
#   'repostedJob': False,
#   'title': 'Software Engineer, Data',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903836162'},
#  {'trackingUrn': 'urn:li:jobPosting:3905328754',
#   'repostedJob': False,
#   'title': 'Staff SW Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9676256',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905328754'},
#  {'trackingUrn': 'urn:li:jobPosting:3905693111',
#   'repostedJob': False,
#   'title': 'Software Engineer, iOS, 7+ Years of Experience',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '98928536',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905693111'},
#  {'trackingUrn': 'urn:li:jobPosting:3904704938',
#   'repostedJob': False,
#   'title': 'Software Engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '178802898',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904704938'},
#  {'trackingUrn': 'urn:li:jobPosting:3902416786',
#   'repostedJob': True,
#   'title': 'Software Test Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '302918039',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902416786'},
#  {'trackingUrn': 'urn:li:jobPosting:3905882126',
#   'repostedJob': False,
#   'title': 'SQL Developer - Snowflake and Python scripting',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905882126'},
#  {'trackingUrn': 'urn:li:jobPosting:3902388878',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '942279396',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902388878'},
#  {'trackingUrn': 'urn:li:jobPosting:3905883086',
#   'repostedJob': False,
#   'title': 'Business Intelligence Engineer / R / Shiny / SQL',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905883086'},
#  {'trackingUrn': 'urn:li:jobPosting:3904507881',
#   'repostedJob': False,
#   'title': 'Java Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560702149',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904507881'},
#  {'trackingUrn': 'urn:li:jobPosting:3905885016',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905885016'},
#  {'trackingUrn': 'urn:li:jobPosting:3905898104',
#   'repostedJob': False,
#   'title': 'Entry Level Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '655495136',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905898104'},
#  {'trackingUrn': 'urn:li:jobPosting:3905300940',
#   'repostedJob': False,
#   'title': 'Lead Software Engineer (001651)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9634197',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905300940'},
#  {'trackingUrn': 'urn:li:jobPosting:3902369002',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902369002'},
#  {'trackingUrn': 'urn:li:jobPosting:3902410942',
#   'repostedJob': True,
#   'title': 'Abinitio Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '490815526',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902410942'},
#  {'trackingUrn': 'urn:li:jobPosting:3906227614',
#   'repostedJob': False,
#   'title': 'Staff FullStack Engineer/Boston/TypeScript',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '427054737',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906227614'},
#  {'trackingUrn': 'urn:li:jobPosting:3906096621',
#   'repostedJob': False,
#   'title': 'SQL Developer with Python',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '985122501',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906096621'},
#  {'trackingUrn': 'urn:li:jobPosting:3906020655',
#   'repostedJob': False,
#   'title': 'software engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '9874302',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906020655'},
#  {'trackingUrn': 'urn:li:jobPosting:3905338394',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer, Data Engineering - ThousandEyes',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '98226753',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905338394'},
#  {'trackingUrn': 'urn:li:jobPosting:3902387952',
#   'repostedJob': False,
#   'title': 'Software Engineer - 2024 Summer Intern',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '195700957',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902387952'},
#  {'trackingUrn': 'urn:li:jobPosting:3904098193',
#   'repostedJob': False,
#   'title': 'Data Engineer Intern (Remote but needs to be in Eastern or Central Time zone)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '15689498',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904098193'},
#  {'trackingUrn': 'urn:li:jobPosting:3904070954',
#   'repostedJob': True,
#   'title': 'Software Engineer II',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '19961175',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904070954'},
#  {'trackingUrn': 'urn:li:jobPosting:3903793861',
#   'repostedJob': True,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '381408903',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903793861'},
#  {'trackingUrn': 'urn:li:jobPosting:3904063059',
#   'repostedJob': True,
#   'title': 'Back End Engineer - Python, AWS, Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '215409969',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904063059'},
#  {'trackingUrn': 'urn:li:jobPosting:3906219418',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '870701010',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906219418'},
#  {'trackingUrn': 'urn:li:jobPosting:3902324966',
#   'repostedJob': False,
#   'title': 'Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
# ...
#   'repostedJob': False,
#   'title': 'Software Developer (Web Development)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '35915755',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901948621'},
#  {'trackingUrn': 'urn:li:jobPosting:3904512117',
#   'repostedJob': False,
#   'title': 'Full Stack Developer (Java/React)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560702149',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904512117'},
#  {'trackingUrn': 'urn:li:jobPosting:3904511149',
#   'repostedJob': False,
#   'title': 'AI Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '560702149',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904511149'},
#  {'trackingUrn': 'urn:li:jobPosting:3905296658',
#   'repostedJob': False,
#   'title': 'Full Stack Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '19972744',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905296658'},
#  {'trackingUrn': 'urn:li:jobPosting:3901953549',
#   'repostedJob': False,
#   'title': 'NMC_000198 - W2 - Data Engineer (React, Python, Hadoop, Cloud))',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '80373254',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901953549'},
#  {'trackingUrn': 'urn:li:jobPosting:3901961298',
#   'repostedJob': False,
#   'title': 'Sr. Software Development Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '215035349',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901961298'},
#  {'trackingUrn': 'urn:li:jobPosting:3885778477',
#   'repostedJob': True,
#   'title': 'Back End Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1448854',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3885778477'},
#  {'trackingUrn': 'urn:li:jobPosting:3905888197',
#   'repostedJob': False,
#   'title': 'Software Engineer - Controls',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '31228454',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905888197'},
#  {'trackingUrn': 'urn:li:jobPosting:3905634974',
#   'repostedJob': False,
#   'title': 'Junior Machine Learning Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905634974'},
#  {'trackingUrn': 'urn:li:jobPosting:3906230311',
#   'repostedJob': False,
#   'title': 'Texas Southern University Full Stack Software Developer Entry Level Opportunity',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '81543038',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906230311'},
#  {'trackingUrn': 'urn:li:jobPosting:3901994520',
#   'repostedJob': False,
#   'title': 'SQL Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901994520'},
#  {'trackingUrn': 'urn:li:jobPosting:3904018281',
#   'repostedJob': False,
#   'title': 'Software Development Engineer, Gen AI, Ballista',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '34045426',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904018281'},
#  {'trackingUrn': 'urn:li:jobPosting:3905850146',
#   'repostedJob': False,
#   'title': 'Full Stack Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1104280679',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905850146'},
#  {'trackingUrn': 'urn:li:jobPosting:3867521921',
#   'repostedJob': True,
#   'title': 'Front End Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '436983732',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3867521921'},
#  {'trackingUrn': 'urn:li:jobPosting:3904027853',
#   'repostedJob': False,
#   'title': 'Software Development Engineer, Gen AI, Ballista',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '34045426',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904027853'},
#  {'trackingUrn': 'urn:li:jobPosting:3889862730',
#   'repostedJob': True,
#   'title': 'Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '149142875',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3889862730'},
#  {'trackingUrn': 'urn:li:jobPosting:3905635247',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer - Backend',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '30204040',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905635247'},
#  {'trackingUrn': 'urn:li:jobPosting:3906093549',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '816385069',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906093549'},
#  {'trackingUrn': 'urn:li:jobPosting:3901988824',
#   'repostedJob': False,
#   'title': 'Senior Software Engineer (Backend + Infra)',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '348965428',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901988824'},
#  {'trackingUrn': 'urn:li:jobPosting:3903846326',
#   'repostedJob': False,
#   'title': 'Data Engineer, Mid',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '267048769',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903846326'},
#  {'trackingUrn': 'urn:li:jobPosting:3903846324',
#   'repostedJob': False,
#   'title': 'Data Engineer, Mid',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '267048769',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903846324'},
#  {'trackingUrn': 'urn:li:jobPosting:3904503233',
#   'repostedJob': False,
#   'title': 'Java/Web Services Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '291796501',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904503233'},
#  {'trackingUrn': 'urn:li:jobPosting:3905292876',
#   'repostedJob': False,
#   'title': 'Database Engineer - 10K Sign on Bonus',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '728470395',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905292876'},
#  {'trackingUrn': 'urn:li:jobPosting:3902389245',
#   'repostedJob': False,
#   'title': 'Senior Java Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '287965060',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902389245'},
#  {'trackingUrn': 'urn:li:jobPosting:3905868153',
#   'repostedJob': True,
#   'title': 'Software Engineer - Durable Objects',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6620189',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905868153'},
#  {'trackingUrn': 'urn:li:jobPosting:3905881370',
#   'repostedJob': False,
#   'title': 'Front End Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '1307337',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905881370'},
#  {'trackingUrn': 'urn:li:jobPosting:3906078751',
#   'repostedJob': False,
#   'title': 'Senior Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '841032685',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3906078751'},
#  {'trackingUrn': 'urn:li:jobPosting:3902385810',
#   'repostedJob': False,
#   'title': 'Data Engineer (II) - Remote',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902385810'},
#  {'trackingUrn': 'urn:li:jobPosting:3902838650',
#   'repostedJob': False,
#   'title': 'Sr Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '70974166',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902838650'},
#  {'trackingUrn': 'urn:li:jobPosting:3903886475',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '195686864',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903886475'},
#  {'trackingUrn': 'urn:li:jobPosting:3902369654',
#   'repostedJob': False,
#   'title': 'Senior Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '530294739',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902369654'},
#  {'trackingUrn': 'urn:li:jobPosting:3905867261',
#   'repostedJob': False,
#   'title': 'Software Engineer, DDoS',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6620189',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905867261'},
#  {'trackingUrn': 'urn:li:jobPosting:3905331671',
#   'repostedJob': False,
#   'title': 'Java Full Stack Developer - Junior or Mid',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '256881782',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905331671'},
#  {'trackingUrn': 'urn:li:jobPosting:3905852965',
#   'repostedJob': False,
#   'title': 'ETL Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905852965'},
#  {'trackingUrn': 'urn:li:jobPosting:3905862764',
#   'repostedJob': True,
#   'title': 'Software Engineer - Distributed Systems',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6620189',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905862764'},
#  {'trackingUrn': 'urn:li:jobPosting:3903851066',
#   'repostedJob': True,
#   'title': 'Software Dev Engineer III, Next Gen Developer Experience',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '7745488',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3903851066'},
#  {'trackingUrn': 'urn:li:jobPosting:3905295768',
#   'repostedJob': False,
#   'title': 'Data and Platform Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '104862232',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905295768'},
#  {'trackingUrn': 'urn:li:jobPosting:3902386715',
#   'repostedJob': False,
#   'title': 'Data Engineer (II) - Remote',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3902386715'},
#  {'trackingUrn': 'urn:li:jobPosting:3905604895',
#   'repostedJob': False,
#   'title': 'Senior Python Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': None,
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_CREATE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905604895'},
#  {'trackingUrn': 'urn:li:jobPosting:3904092336',
#   'repostedJob': False,
#   'title': 'Senior Software Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '440143621',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904092336'},
#  {'trackingUrn': 'urn:li:jobPosting:3904059713',
#   'repostedJob': True,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '22140761',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904059713'},
#  {'trackingUrn': 'urn:li:jobPosting:3901958379',
#   'repostedJob': False,
#   'title': 'Senior Data Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '71572340',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901958379'},
#  {'trackingUrn': 'urn:li:jobPosting:3905694800',
#   'repostedJob': True,
#   'title': 'Software Engineer, Web Frameworks',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '6620189',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3905694800'},
#  {'trackingUrn': 'urn:li:jobPosting:3904589874',
#   'repostedJob': False,
#   'title': 'Python and Linux Developer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '47622752',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3904589874'}]

# %%
len(jobs)
# Out:
# 1000

# %%
jobs[:1]
# Out:
# [{'trackingUrn': 'urn:li:jobPosting:3901990442',
#   'repostedJob': False,
#   'title': 'Software Engineer',
#   '$recipeTypes': ['com.linkedin.deco.recipe.anonymous.Anon1578943416'],
#   'posterId': '823990701',
#   '$type': 'com.linkedin.voyager.dash.jobs.JobPosting',
#   'contentSource': 'JOBS_PREMIUM_OFFLINE',
#   'entityUrn': 'urn:li:fsd_jobPosting:3901990442'}]

# %%
job = api.get_job('3901990442')
job
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:3901990442',
#  'companyDetails': {'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany': {'companyResolutionResult': {'entityUrn': 'urn:li:fs_normalized_company:1035',
#     'name': 'Microsoft',
#     'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#          'fileIdentifyingUrlPathSegment': '200_200/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=KOdHg1YMVP4kHJMXhg4I7YRKL_JGUxZDEoz7u8XJv7M',
#          'expiresAt': 1721865600000,
#          'height': 200},
#         {'width': 100,
#          'fileIdentifyingUrlPathSegment': '100_100/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=mCZCxEqBStCNBAi96md0OfNgjoji_eRicmWD9uYeu-4',
#          'expiresAt': 1721865600000,
#          'height': 100},
#         {'width': 400,
#          'fileIdentifyingUrlPathSegment': '400_400/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=tBwsEKEuwpNB1Dzvnr-whieatv6MKlNAe8MFe9I099Q',
#          'expiresAt': 1721865600000,
#          'height': 400}],
#        'rootUrl': 'https://media.licdn.com/dms/image/C560BAQE88xCsONDULQ/company-logo_'}},
#      'type': 'SQUARE_LOGO'},
#     '$recipeType': 'com.linkedin.voyager.deco.organization.shared.WebCompactCompany',
#     'universalName': 'microsoft',
#     'url': 'https://www.linkedin.com/company/microsoft'},
#    'company': 'urn:li:fs_normalized_company:1035',
#    '$recipeType': 'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany'}},
#  'jobState': 'LISTED',
#  'description': {'attributes': [{'start': 19,
#     'length': 6,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 25,
#     'length': 21,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 46,
#     'length': 16,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 246,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 247,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 736,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 737,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 761,
#     'length': 17,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 981,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 982,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1362,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1363,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1527,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1528,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1545,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1546,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1529,
#     'length': 18,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 1695,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1696,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1697,
#     'length': 23,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 1917,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1918,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 1919,
#     'length': 20,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2122,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2123,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2124,
#     'length': 15,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2341,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2342,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2343,
#     'length': 14,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2428,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2429,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2430,
#     'length': 17,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2683,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2684,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2690,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2691,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2685,
#     'length': 7,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2723,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2724,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2739,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2740,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2725,
#     'length': 16,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2765,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2766,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2741,
#     'length': 26,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 2767,
#     'length': 184,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 2976,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2951,
#     'length': 26,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 2951,
#     'length': 26,
#     'type': {'com.linkedin.pemberly.text.List': {'ordered': False}},
#     'attributeKindUnion': {'list': {'ordered': False}}},
#    {'start': 2767,
#     'length': 210,
#     'type': {'com.linkedin.pemberly.text.List': {'ordered': False}},
#     'attributeKindUnion': {'list': {'ordered': False}}},
#    {'start': 2995,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2996,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 2977,
#     'length': 20,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 3242,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3243,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3371,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3372,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3244,
#     'length': 129,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 3244,
#     'length': 129,
#     'type': {'com.linkedin.pemberly.text.List': {'ordered': False}},
#     'attributeKindUnion': {'list': {'ordered': False}}},
#    {'start': 3397,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3398,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 3373,
#     'length': 26,
#     'type': {'com.linkedin.pemberly.text.Bold': {}},
#     'attributeKindUnion': {'bold': {}}},
#    {'start': 3399,
#     'length': 181,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 3580,
#     'length': 154,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 3734,
#     'length': 166,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 3900,
#     'length': 102,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 4002,
#     'length': 131,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 4179,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4180,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4133,
#     'length': 48,
#     'type': {'com.linkedin.pemberly.text.ListItem': {}},
#     'attributeKindUnion': {'listItem': {}}},
#    {'start': 3399,
#     'length': 782,
#     'type': {'com.linkedin.pemberly.text.List': {'ordered': False}},
#     'attributeKindUnion': {'list': {'ordered': False}}},
#    {'start': 4530,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4531,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4702,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4703,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4773,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4774,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4785,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4786,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4795,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}},
#    {'start': 4796,
#     'length': 1,
#     'type': {'com.linkedin.pemberly.text.LineBreak': {}},
#     'attributeKindUnion': {'lineBreak': {}}}],
#   'text': "The mission of our Azure Customer Experience (CXP) Primo Team is to empower our customers to achieve success with Microsoft Cloud products, receiving high-quality world-class assistance whenever and wherever they need it throughout their journey.\n\nWe are a fast, and dynamic team with a startup culture that loves to take on big challenges, solve them and move onto the next. We have a vibrant developer ecosystem that is constantly growing coupled with steady adoption by many Microsoft services that is constantly challenging us with high scalability design problems. As a member of the team, you’d be getting opportunities to deal with these technical challenges on a regular basis and take our platform innovation to the next level.\n\nWe are actively hiring Software Engineer to join the Quality Central Engineering Team within Azure Customer Experience (CXP) Primo, responsible for designing and building scalable and secure software solutions for increasing Azure reliability.\n\nMicrosoft’s mission is to empower every person and every organization on the planet to achieve more. As employees we come together with a growth mindset, innovate to empower others, and collaborate to realize our shared goals. Each day we build on our values of respect, integrity, and accountability to create a culture of inclusion where everyone can thrive at work and beyond.\n\nIn alignment with our Microsoft values, we are committed to cultivating an inclusive work environment for all employees to positively impact our culture every day.\n\nResponsibilities\n\nAs a Primo Software Engineer, you will be responsible for building reliable, scalable, and high-performance solutions. Key responsibilities include:\n\nDevelopment Lifecycle: A successful candidate should have experience in multiple phases of development cycle and will leverage this experience to design, build, deploy, and maintain online support features for customers.\n\nTechnical Excellence: SWEs demonstrate a passion for technology, a curiosity to ‘go deep,’ and an ability to quickly learn, estimate the work effort and build upon past experiences to deliver innovation.\n\nCollaboration: Our engineers work with others within an immediate team, as well as across business units and various groups of the company to co-create solutions and have competent written & oral communication skills.\n\nCustomer Focus: Understands how engineering decisions result in added customer value.\n\nDrive For Results: Our SWEs are flexible, adapt to any situation, and navigate ambiguity to solve problems and eliminate obstacles to delivering on-time results. They also demonstrate good decision-making, conflict resolution, and follow through skills.\n\nOther\n\n\u202f Embody our culture and values\n\nQualifications\n\nRequired Qualifications:\n\nBachelor's Degree in Computer Science, or related technical discipline with proven experience coding in languages including, but not limited to, C, C++, C#, Java, JavaScript, or PythonOR equivalent experience.\nOther Requirements\n\nAbility to meet Microsoft, customer and/or government security screening requirements are required for this role. These requirements include, but are not limited to the following specialized security screenings: Microsoft Cloud Background Check:\n\nThis position will be required to pass the Microsoft Cloud background check upon hire/transfer and every two years thereafter. \n\nPreferred Qualifications\n\n2+ years of experience as a Software Engineer or Software Developer and with coding and debugging in languages such as C#, C++, Java, Python or similar modern development languages Experience/ knowledge of frameworks such as Angular.js, React and with cloud technologies such as Microsoft Azure, AWS, PCF or similar could technologies Experience working in Agile process such as SAFE or similar Agile methodologies and with analysis tools such as Azure Data Lake, Azure Data factory or similar tools. Deep understanding of data structures, algo ...
#  'title': 'Software Engineer',
#  'entityUrn': 'urn:li:fs_normalized_jobPosting:3901990442',
#  'workRemoteAllowed': False,
#  'applyMethod': {'com.linkedin.voyager.jobs.OffsiteApply': {'applyStartersPreferenceVoid': True,
#    'companyApplyUrl': 'https://careers.microsoft.com/us/en/job/1710305/Software-Engineer?jobsource=linkedin&utm_source=Job%20Board&utm_campaign=linkedin-feed',
#    'inPageOffsiteApply': False}},
#  'talentHubJob': False,
#  'formattedLocation': 'Charlotte, NC',
#  'workplaceTypes': ['urn:li:fs_workplaceType:3'],
#  'listedAt': 1713496639000,
#  'jobPostingId': 3901990442,
#  '$recipeType': 'com.linkedin.voyager.deco.jobs.web.shared.WebLightJobPosting',
#  'workplaceTypesResolutionResults': {'urn:li:fs_workplaceType:3': {'localizedName': 'Hybrid',
#    '$recipeType': 'com.linkedin.voyager.deco.jobs.shared.WebJobDetailsWorkplaceType',
#    'entityUrn': 'urn:li:fs_workplaceType:3'}}}

# %%
job_skills = api.get_job_skills('3901990442')
# job_skills = api.get_job_skills('3901990442')
job_skills
# Out:
# {'shouldShowJobSkillsFeedback': True,
#  'skillLimitInsight': {'image': {'attributes': [{'tintColor': 'ICON',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#      'detailDataUnion': {'systemImage': 'SYS_ICN_SIGNAL_NOTICE_SMALL'}}],
#    '$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel'},
#   '$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#   'text': {'textDirection': 'USER_LOCALE',
#    '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#    'text': 'You can manage all your skills on your profile. Edit skills',
#    'attributesV2': [{'start': 48,
#      'length': 11,
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#      'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/in/sudarshandudhe/details/skills?profileUrn=urn%3Ali%3Afsd_profile%3AACoAABmW8OcBkHVy3a_d6KXoLULumL_yKix-YOw'}},
#     {'start': 48,
#      'length': 11,
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#      'detailDataUnion': {'style': 'BOLD'}}]}},
#  'detailsContent': {'textDirection': 'USER_LOCALE',
#   '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#   'text': '4 skills found on your profile match the skills associated with the job. Learn more',
#   'attributesV2': [{'start': 73,
#     'length': 10,
#     '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#     'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/help/linkedin/answer/a793433?lang=en'}},
#    {'start': 73,
#     'length': 10,
#     '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#     'detailDataUnion': {'style': 'BOLD'}}],
#   'accessibilityText': 'Learn more about how your skills are matched'},
#  'detailsTitle': {'textDirection': 'USER_LOCALE',
#   '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#   'text': 'Skill details',
#   'attributesV2': []},
#  'skillMatchStatuses': [{'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:438',
#    'localizedSkillDisplayName': 'C (Programming Language)',
#    'skillOnProfile': True,
#    'skill': {'name': 'C (Programming Language)',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:438'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile shows you have C (Programming Language) as a skill. C (Programming Language) matches the job description.'},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:1541',
#    'localizedSkillDisplayName': 'Computer Science',
#    'skillOnProfile': True,
#    'skill': {'name': 'Computer Science',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:1541'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile shows you have Computer Science as a skill. Computer Science matches the job description.'},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:698',
#    'localizedSkillDisplayName': 'Programming',
#    'skillOnProfile': True,
#    'skill': {'name': 'Programming',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:698'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile shows you have Programming as a skill. Programming matches the job description.'},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:602',
#    'localizedSkillDisplayName': 'Software Development',
#    'skillOnProfile': True,
#    'skill': {'name': 'Software Development',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:602'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile shows you have Software Development as a skill. Software Development matches the job description.'},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:3203',
#    'localizedSkillDisplayName': 'Analytical Skills',
#    'skillOnProfile': False,
#    'skill': {'name': 'Analytical Skills',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:3203'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show Analytical Skills as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A3203',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add Analytical Skills as a skill to your profile'}}},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:135',
#    'localizedSkillDisplayName': 'Communication',
#    'skillOnProfile': False,
#    'skill': {'name': 'Communication',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:135'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show Communication as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A135',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add Communication as a skill to your profile'}}},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:2287',
#    'localizedSkillDisplayName': 'High Performance Computing (HPC)',
#    'skillOnProfile': False,
#    'skill': {'name': 'High Performance Computing (HPC)',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:2287'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show High Performance Computing (HPC) as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A2287',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add High Performance Computing (HPC) as a skill to your profile'}}},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:28720',
#    'localizedSkillDisplayName': 'Online Support',
#    'skillOnProfile': False,
#    'skill': {'name': 'Online Support',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:28720'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show Online Support as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A28720',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add Online Support as a skill to your profile'}}},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:43837',
#    'localizedSkillDisplayName': 'Oral Communication',
#    'skillOnProfile': False,
#    'skill': {'name': 'Oral Communication',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:43837'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show Oral Communication as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A43837',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add Oral Communication as a skill to your profile'}}},
#   {'skillAssessmentVerified': False,
#    'skillUrn': 'urn:li:fsd_standardizedSkill:1017',
#    'localizedSkillDisplayName': 'Problem Solving',
#    'skillOnProfile': False,
#    'skill': {'name': 'Problem Solving',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#     'entityUrn': 'urn:li:fsd_standardizedSkill:1017'},
#    '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#    'accessibilityText': 'Your profile does not show Problem Solving as a skill. If you have this skill, you can add it to your profile.',
#    'skillMatchActionButton': {'icon': 'SYS_ICN_ADD_SMALL',
#     'controlName': 'add_skill',
#     'actionUrl': 'https://www.linkedin.com/in/sudarshandudhe/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A1017',
#     '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#     'text': {'textDirection': 'USER_LOCALE',
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#      'text': 'Add',
#      'attributesV2': [],
#      'accessibilityTextAttributesV2': [],
#      'accessibilityText': 'Add Problem Solving as a skill to your profile'}}}],
#  'companyUrn': 'urn:li:fsd_company:1035',
#  'insightSummary': {'image': {'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#      'detailDataUnion': {'systemImage': 'SYS_ICN_CHECKLIST_MEDIUM'}}],
#    '$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel'},
#   '$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#   'text': {'textDirection': 'USER_LOCALE',
#    '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#    'text': 'Skills: Computer Science, Software Development, +8 more',
#    'attributesV2': [{'start': 0,
#      'length': 55,
#      '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#      'detailDataUnion': {'hyperlink': '#HYM'}}]}},
#  'jobSkillsVersion': 'WATERLOO_STANDARDIZED_EXP2',
#  'entityUrn': 'urn:li:fsd_jobSkillMatchInsight:3901990442',
#  'trackingReferenceId': 'ò2^Ë:\x9d@s\x88Øoð\x86\x18?L',
#  'company': {'name': 'Microsoft',
#   'logo': {'vectorImage': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorImageOnlyRootUrl',
#     'rootUrl': 'https://media.licdn.com/dms/image/C560BAQE88xCsONDULQ/company-logo_',
#     'artifacts': [{'width': 200,
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#       'fileIdentifyingUrlPathSegment': '200_200/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=KOdHg1YMVP4kHJMXhg4I7YRKL_JGUxZDEoz7u8XJv7M',
#       'expiresAt': 1721865600000,
#       'height': 200},
#      {'width': 100,
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#       'fileIdentifyingUrlPathSegment': '100_100/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=mCZCxEqBStCNBAi96md0OfNgjoji_eRicmWD9uYeu-4',
#       'expiresAt': 1721865600000,
#       'height': 100},
#      {'width': 400,
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#       'fileIdentifyingUrlPathSegment': '400_400/0/1630652622688/microsoft_logo?e=1721865600&v=beta&t=tBwsEKEuwpNB1Dzvnr-whieatv6MKlNAe8MFe9I099Q',
#       'expiresAt': 1721865600000,
#       'height': 400}]}},
#   '$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1326778634',
#   'entityUrn': 'urn:li:fsd_company:1035'},
#  '$recipeType': 'com.linkedin.voyager.dash.deco.assessments.FullJobSkillMatchInsight',
#  'detailsHeader': {'textDirection': 'USER_LOCALE',
#   '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#   'text': 'Skills associated with the job',
#   'attributesV2': []}}

# %%
# pip install jobspy

# %%
# from jobspy import scrape_jobs
# # scrape_jobs
